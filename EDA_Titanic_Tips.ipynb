# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Assignment-1-specification" data-toc-modified-id="Assignment-1-specification-1">Assignment 1 specification</a></span><ul class="toc-item"><li><span><a href="#Which-datasets-to-consider?" data-toc-modified-id="Which-datasets-to-consider?-1.1">Which datasets to consider?</a></span><ul class="toc-item"><li><span><a href="#Table-of-content-:" data-toc-modified-id="Table-of-content-:-1.1.1">Table of content :</a></span></li><li><span><a href="#This-is-section-b" data-toc-modified-id="This-is-section-b-1.1.2"><a name="section_b" rel="nofollow"></a>This is section b</a></span></li></ul></li></ul></li><li><span><a href="#Task-1:-First-pass---load-data-set-and-initial-clean" data-toc-modified-id="Task-1:-First-pass---load-data-set-and-initial-clean-2">Task 1: First pass - load data set and initial clean</a></span><ul class="toc-item"><li><span><a href="#Step-1-ideas-:" data-toc-modified-id="Step-1-ideas-:-2.1">Step 1 ideas :</a></span><ul class="toc-item"><li><span><a href="#1.1--Replacing-Embarked-missing-values-with-.fillna('S')" data-toc-modified-id="1.1--Replacing-Embarked-missing-values-with-.fillna('S')-2.1.1">1.1- Replacing Embarked missing values with .fillna('S')</a></span></li><li><span><a href="#1.2--Add-a-new-categories-:-Unknow-for-Cabin's-location" data-toc-modified-id="1.2--Add-a-new-categories-:-Unknow-for-Cabin's-location-2.1.2">1.2- Add a new categories : Unknow for Cabin's location</a></span></li><li><span><a href="#1.3-New-categorical-title-column-based-on-the-name" data-toc-modified-id="1.3-New-categorical-title-column-based-on-the-name-2.1.3">1.3-New categorical title column based on the name</a></span></li><li><span><a href="#1.4-Fare,-0-values-treatments" data-toc-modified-id="1.4-Fare,-0-values-treatments-2.1.4">1.4-Fare, 0 values treatments</a></span></li><li><span><a href="#1.5-Fare-skewed/outliner-need-to-remove-and-transform-(Fare_range)" data-toc-modified-id="1.5-Fare-skewed/outliner-need-to-remove-and-transform-(Fare_range)-2.1.5">1.5-Fare skewed/outliner need to remove and transform (Fare_range)</a></span></li><li><span><a href="#1.6-Age-Missing-values-:" data-toc-modified-id="1.6-Age-Missing-values-:-2.1.6">1.6-Age Missing values :</a></span></li></ul></li></ul></li><li><span><a href="#Final-touch" data-toc-modified-id="Final-touch-3">Final touch</a></span></li><li><span><a href="#Task-2:-Second-pass---individual-features-and-target" data-toc-modified-id="Task-2:-Second-pass---individual-features-and-target-4">Task 2: Second pass - individual features and target</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#-This-is-section-A" data-toc-modified-id="-This-is-section-A-4.0.1"><a name="section_a" rel="nofollow"></a> This is section A</a></span></li></ul></li><li><span><a href="#Task-2-ideas-:" data-toc-modified-id="Task-2-ideas-:-4.1">Task 2 ideas :</a></span></li></ul></li><li><span><a href="#Target-:-Survived" data-toc-modified-id="Target-:-Survived-5">Target : Survived</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Interpretation-:" data-toc-modified-id="Interpretation-:-5.0.1">Interpretation :</a></span></li></ul></li><li><span><a href="#Global-survival-rate-:-38%" data-toc-modified-id="Global-survival-rate-:-38%-5.1">Global survival rate : 38%</a></span><ul class="toc-item"><li><span><a href="#-------------------------------------Categorical-features-------------------------------------" data-toc-modified-id="-------------------------------------Categorical-features--------------------------------------5.1.1">-------------------------------------Categorical features-------------------------------------</a></span></li><li><span><a href="#Pclass---1st,-2nd-and-3rd-class" data-toc-modified-id="Pclass---1st,-2nd-and-3rd-class-5.1.2">Pclass - 1st, 2nd and 3rd class</a></span></li><li><span><a href="#Interpretation-:" data-toc-modified-id="Interpretation-:-5.1.3">Interpretation :</a></span></li><li><span><a href="#Fare_range---Money-and-survival-rates" data-toc-modified-id="Fare_range---Money-and-survival-rates-5.1.4">Fare_range - Money and survival rates</a></span></li><li><span><a href="#Interpretation-:" data-toc-modified-id="Interpretation-:-5.1.5">Interpretation :</a></span></li><li><span><a href="#Title-class---Do-important-people-come-first-?" data-toc-modified-id="Title-class---Do-important-people-come-first-?-5.1.6">Title class - Do important people come first ?</a></span></li><li><span><a href="#Interpretation-:" data-toc-modified-id="Interpretation-:-5.1.7">Interpretation :</a></span></li><li><span><a href="#Deck---Position-of-cabin-relative-to-flood-+-Unknow(missing-values)" data-toc-modified-id="Deck---Position-of-cabin-relative-to-flood-+-Unknow(missing-values)-5.1.8">Deck - Position of cabin relative to flood + Unknow(missing values)</a></span></li><li><span><a href="#Interpretation-:" data-toc-modified-id="Interpretation-:-5.1.9">Interpretation :</a></span></li><li><span><a href="#Embarked---Does-the-city-you-come-from-matters?(different-countries)" data-toc-modified-id="Embarked---Does-the-city-you-come-from-matters?(different-countries)-5.1.10">Embarked - Does the city you come from matters?(different countries)</a></span></li><li><span><a href="#Interpretation-:" data-toc-modified-id="Interpretation-:-5.1.11">Interpretation :</a></span></li><li><span><a href="#Sex---Woman-first-?" data-toc-modified-id="Sex---Woman-first-?-5.1.12">Sex - Woman first ?</a></span></li><li><span><a href="#Interpretation" data-toc-modified-id="Interpretation-5.1.13">Interpretation</a></span></li><li><span><a href="#-------------------------------------Numerical-features-------------------------------------" data-toc-modified-id="-------------------------------------Numerical-features--------------------------------------5.1.14">-------------------------------------Numerical features-------------------------------------</a></span></li><li><span><a href="#2.2.1---Age---Childrens,-Adult-and-Elderly" data-toc-modified-id="2.2.1---Age---Childrens,-Adult-and-Elderly-5.1.15">2.2.1 - Age - Childrens, Adult and Elderly</a></span></li><li><span><a href="#Interpretation-:" data-toc-modified-id="Interpretation-:-5.1.16">Interpretation :</a></span></li><li><span><a href="#2.2.2---SibSp--Siblings-and-Spouse" data-toc-modified-id="2.2.2---SibSp--Siblings-and-Spouse-5.1.17">2.2.2 - SibSp -Siblings and Spouse</a></span></li><li><span><a href="#Interpretation-:" data-toc-modified-id="Interpretation-:-5.1.18">Interpretation :</a></span></li><li><span><a href="#2.2.3---Parch---Parents-and-Childrens" data-toc-modified-id="2.2.3---Parch---Parents-and-Childrens-5.1.19">2.2.3 - Parch - Parents and Childrens</a></span></li><li><span><a href="#Interpretation-:" data-toc-modified-id="Interpretation-:-5.1.20">Interpretation :</a></span></li></ul></li></ul></li><li><span><a href="#Task-2-Conclusion-:" data-toc-modified-id="Task-2-Conclusion-:-6">Task 2 Conclusion :</a></span></li><li><span><a href="#Task-3:-Third-pass---relationships-between-features-and-target" data-toc-modified-id="Task-3:-Third-pass---relationships-between-features-and-target-7">Task 3: Third pass - relationships between features and target</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Task-3-ideas-:" data-toc-modified-id="Task-3-ideas-:-7.0.1">Task 3 ideas :</a></span></li></ul></li><li><span><a href="#2.3.0---A-little-bit-of-data-engineering--family_size" data-toc-modified-id="2.3.0---A-little-bit-of-data-engineering--family_size-7.1">2.3.0 - A little bit of data engineering -family_size</a></span><ul class="toc-item"><li><span><a href="#Interpretation-:" data-toc-modified-id="Interpretation-:-7.1.1">Interpretation :</a></span></li><li><span><a href="#Phik_matrix" data-toc-modified-id="Phik_matrix-7.1.2">Phik_matrix</a></span></li><li><span><a href="#Intrpretation-:" data-toc-modified-id="Intrpretation-:-7.1.3">Intrpretation :</a></span></li></ul></li><li><span><a href="#2.3.1.1---Money-related-features-impact-on-Survival-rates" data-toc-modified-id="2.3.1.1---Money-related-features-impact-on-Survival-rates-7.2">2.3.1.1 - Money related features impact on Survival rates</a></span><ul class="toc-item"><li><span><a href="#Interpretation-:" data-toc-modified-id="Interpretation-:-7.2.1">Interpretation :</a></span></li><li><span><a href="#Interpretation-:" data-toc-modified-id="Interpretation-:-7.2.2">Interpretation :</a></span></li><li><span><a href="#2.3.1.2---Deck-with-other's-features" data-toc-modified-id="2.3.1.2---Deck-with-other's-features-7.2.3">2.3.1.2 - Deck with other's features</a></span></li><li><span><a href="#Interpretation-:" data-toc-modified-id="Interpretation-:-7.2.4">Interpretation :</a></span></li><li><span><a href="#2.3.1.3----Embarked-with-other's-features" data-toc-modified-id="2.3.1.3----Embarked-with-other's-features-7.2.5">2.3.1.3 -  Embarked with other's features</a></span></li><li><span><a href="#Interpretation-:" data-toc-modified-id="Interpretation-:-7.2.6">Interpretation :</a></span></li></ul></li><li><span><a href="#2.3.2---Morality-related-features,-impact-on-Survival-rates" data-toc-modified-id="2.3.2---Morality-related-features,-impact-on-Survival-rates-7.3">2.3.2 - Morality related features, impact on Survival rates</a></span><ul class="toc-item"><li><span><a href="#2.3.2.1--Age-againts-Title---Do-we-save-children-and-elderly-first-or-important_people-?" data-toc-modified-id="2.3.2.1--Age-againts-Title---Do-we-save-children-and-elderly-first-or-important_people-?-7.3.1">2.3.2.1 -Age againts Title - Do we save children and elderly first or important_people ?</a></span></li><li><span><a href="#Interpretation-:" data-toc-modified-id="Interpretation-:-7.3.2">Interpretation :</a></span></li><li><span><a href="#2.3.2.2---Do-passengers-family-dies-together-?-Or-do-they-split-them-?" data-toc-modified-id="2.3.2.2---Do-passengers-family-dies-together-?-Or-do-they-split-them-?-7.3.3">2.3.2.2 - Do passengers family dies together ? Or do they split them ?</a></span></li><li><span><a href="#Interpretation-:" data-toc-modified-id="Interpretation-:-7.3.4">Interpretation :</a></span></li></ul></li><li><span><a href="#Main-conclusion-:" data-toc-modified-id="Main-conclusion-:-7.4">Main conclusion :</a></span></li></ul></li><li><span><a href="#Task-1:-First-pass---load-data-set-and-initial-clean" data-toc-modified-id="Task-1:-First-pass---load-data-set-and-initial-clean-8">Task 1: First pass - load data set and initial clean</a></span></li><li><span><a href="#Task-2:-Second-pass---individual-features-and-target" data-toc-modified-id="Task-2:-Second-pass---individual-features-and-target-9">Task 2: Second pass - individual features and target</a></span></li><li><span><a href="#TIPS" data-toc-modified-id="TIPS-10">TIPS</a></span></li><li><span><a href="#2.1-When-do-people-tip-the-most-?" data-toc-modified-id="2.1-When-do-people-tip-the-most-?-11">2.1-When do people tip the most ?</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#-------------------------------------Numerical-Features-------------------------------------" data-toc-modified-id="-------------------------------------Numerical-Features--------------------------------------11.0.1">-------------------------------------Numerical Features-------------------------------------</a></span></li></ul></li><li><span><a href="#2.1.1-Tip_amount-distribution" data-toc-modified-id="2.1.1-Tip_amount-distribution-11.1">2.1.1-Tip_amount distribution</a></span></li><li><span><a href="#2.1.2-Tip_percentage-and-tip-:-Is-there-a-social-norm-?(fixed-tip-percentage)" data-toc-modified-id="2.1.2-Tip_percentage-and-tip-:-Is-there-a-social-norm-?(fixed-tip-percentage)-11.2">2.1.2-Tip_percentage and tip : Is there a social norm ?(fixed tip percentage)</a></span><ul class="toc-item"><li><span><a href="#Interpetation-:" data-toc-modified-id="Interpetation-:-11.2.1">Interpetation :</a></span></li></ul></li><li><span><a href="#2.1.3-Total_bill-and-tip-:" data-toc-modified-id="2.1.3-Total_bill-and-tip-:-11.3">2.1.3-Total_bill and tip :</a></span><ul class="toc-item"><li><span><a href="#Interpetation-:" data-toc-modified-id="Interpetation-:-11.3.1">Interpetation :</a></span></li></ul></li><li><span><a href="#2.1.4-Size-of-group-and-tip:" data-toc-modified-id="2.1.4-Size-of-group-and-tip:-11.4">2.1.4-Size of group and tip:</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Interpetation-:" data-toc-modified-id="Interpetation-:-11.4.0.1">Interpetation :</a></span></li></ul></li><li><span><a href="#-------------------------------------Categorical-features-------------------------------------" data-toc-modified-id="-------------------------------------Categorical-features--------------------------------------11.4.1">-------------------------------------Categorical features-------------------------------------</a></span></li></ul></li><li><span><a href="#2.1.5-Gender-and-tip-:" data-toc-modified-id="2.1.5-Gender-and-tip-:-11.5">2.1.5-Gender and tip :</a></span><ul class="toc-item"><li><span><a href="#Interpetation-:" data-toc-modified-id="Interpetation-:-11.5.1">Interpetation :</a></span></li></ul></li><li><span><a href="#2.1.6-Eating_time-lunch/dinner-and-tip-:" data-toc-modified-id="2.1.6-Eating_time-lunch/dinner-and-tip-:-11.6">2.1.6-Eating_time lunch/dinner and tip :</a></span><ul class="toc-item"><li><span><a href="#Interpetation-:" data-toc-modified-id="Interpetation-:-11.6.1">Interpetation :</a></span></li></ul></li><li><span><a href="#2.1.7-Day-and-tip-:" data-toc-modified-id="2.1.7-Day-and-tip-:-11.7">2.1.7-Day and tip :</a></span><ul class="toc-item"><li><span><a href="#Interpetation-:" data-toc-modified-id="Interpetation-:-11.7.1">Interpetation :</a></span></li></ul></li><li><span><a href="#2.1.8-Smoker-and-tip-:" data-toc-modified-id="2.1.8-Smoker-and-tip-:-11.8">2.1.8-Smoker and tip :</a></span><ul class="toc-item"><li><span><a href="#Interpetation-:" data-toc-modified-id="Interpetation-:-11.8.1">Interpetation :</a></span></li></ul></li><li><span><a href="#Main-conclusion-:" data-toc-modified-id="Main-conclusion-:-11.9">Main conclusion :</a></span></li><li><span><a href="#2.2--When-are-the-table_size-the-largest-?" data-toc-modified-id="2.2--When-are-the-table_size-the-largest-?-11.10">2.2 -When are the table_size the largest ?</a></span><ul class="toc-item"><li><span><a href="#-------------------------------------Numerical-features-------------------------------------" data-toc-modified-id="-------------------------------------Numerical-features--------------------------------------11.10.1">-------------------------------------Numerical features-------------------------------------</a></span></li><li><span><a href="#-------------------------------------Categorical-features-------------------------------------" data-toc-modified-id="-------------------------------------Categorical-features--------------------------------------11.10.2">-------------------------------------Categorical features-------------------------------------</a></span></li><li><span><a href="#2.2.1-Smoking-and-table_size---Does-it-bring-a-big-difference-?" data-toc-modified-id="2.2.1-Smoking-and-table_size---Does-it-bring-a-big-difference-?-11.10.3">2.2.1-Smoking and table_size - Does it bring a big difference ?</a></span></li><li><span><a href="#2.2.2-Eating_time-and-table_size---Does-it-bring-a-big-difference-?" data-toc-modified-id="2.2.2-Eating_time-and-table_size---Does-it-bring-a-big-difference-?-11.10.4">2.2.2-Eating_time and table_size - Does it bring a big difference ?</a></span></li><li><span><a href="#2.2.3-Day-and-table_size---Does-it-bring-a-big-difference-?" data-toc-modified-id="2.2.3-Day-and-table_size---Does-it-bring-a-big-difference-?-11.10.5">2.2.3-Day and table_size - Does it bring a big difference ?</a></span></li><li><span><a href="#2.2.4-Sex-and-table_size---Does-it-bring-a-big-difference-?" data-toc-modified-id="2.2.4-Sex-and-table_size---Does-it-bring-a-big-difference-?-11.10.6">2.2.4-Sex and table_size - Does it bring a big difference ?</a></span></li></ul></li><li><span><a href="#Main-Conclusion-:" data-toc-modified-id="Main-Conclusion-:-11.11">Main Conclusion :</a></span></li><li><span><a href="#2.3-When-do-people-pay-the-most(total_bill)-?" data-toc-modified-id="2.3-When-do-people-pay-the-most(total_bill)-?-11.12">2.3-When do people pay the most(total_bill) ?</a></span><ul class="toc-item"><li><span><a href="#-------------------------------------Numerical-features-------------------------------------" data-toc-modified-id="-------------------------------------Numerical-features--------------------------------------11.12.1">-------------------------------------Numerical features-------------------------------------</a></span></li><li><span><a href="#2.3.1-Table_size-and-total_bill" data-toc-modified-id="2.3.1-Table_size-and-total_bill-11.12.2">2.3.1-Table_size and total_bill</a></span></li><li><span><a href="#Interpetation-:" data-toc-modified-id="Interpetation-:-11.12.3">Interpetation :</a></span></li><li><span><a href="#2.3.2-Tip-and-total_bill" data-toc-modified-id="2.3.2-Tip-and-total_bill-11.12.4">2.3.2-Tip and total_bill</a></span></li><li><span><a href="#-------------------------------------Categorical-features-------------------------------------" data-toc-modified-id="-------------------------------------Categorical-features--------------------------------------11.12.5">-------------------------------------Categorical features-------------------------------------</a></span></li><li><span><a href="#2.3.3-Gender-and-total_bill-does-it-matter-?" data-toc-modified-id="2.3.3-Gender-and-total_bill-does-it-matter-?-11.12.6">2.3.3-Gender and total_bill does it matter ?</a></span></li><li><span><a href="#Interpetation-:" data-toc-modified-id="Interpetation-:-11.12.7">Interpetation :</a></span></li><li><span><a href="#2.3.4-Day-and-total_bill-does-it-matter-?" data-toc-modified-id="2.3.4-Day-and-total_bill-does-it-matter-?-11.12.8">2.3.4-Day and total_bill does it matter ?</a></span></li><li><span><a href="#Interpetation:" data-toc-modified-id="Interpetation:-11.12.9">Interpetation:</a></span></li><li><span><a href="#2.3.5-Eating_time-and-total_bill-does-it-matter-?" data-toc-modified-id="2.3.5-Eating_time-and-total_bill-does-it-matter-?-11.12.10">2.3.5-Eating_time and total_bill does it matter ?</a></span></li><li><span><a href="#Interpetation-:" data-toc-modified-id="Interpetation-:-11.12.11">Interpetation :</a></span></li><li><span><a href="#2.3.6-Smoker-and-total_bill-does-it-matter-?" data-toc-modified-id="2.3.6-Smoker-and-total_bill-does-it-matter-?-11.12.12">2.3.6 Smoker and total_bill does it matter ?</a></span></li><li><span><a href="#Interpetation-:" data-toc-modified-id="Interpetation-:-11.12.13">Interpetation :</a></span></li></ul></li><li><span><a href="#Main-conclusion-:" data-toc-modified-id="Main-conclusion-:-11.13">Main conclusion :</a></span></li></ul></li><li><span><a href="#Task-2-Summary---:" data-toc-modified-id="Task-2-Summary---:-12">Task 2 Summary   :</a></span></li><li><span><a href="#Task-3:-Third-pass---relationships-between-features-and-target" data-toc-modified-id="Task-3:-Third-pass---relationships-between-features-and-target-13">Task 3: Third pass - relationships between features and target</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#In-task-2-we-saw-the-relationship-between-one-feature--at-a-time-and-our-target.-Let's-check-this-time-with-a-phik_matrix-that-will-display-the-phik's-coefficient-between-all-our-features-and-target." data-toc-modified-id="In-task-2-we-saw-the-relationship-between-one-feature--at-a-time-and-our-target.-Let's-check-this-time-with-a-phik_matrix-that-will-display-the-phik's-coefficient-between-all-our-features-and-target.-13.0.1">In task 2 we saw the relationship between one feature  at a time and our target. Let's check this time with a phik_matrix that will display the phik's coefficient between all our features and target.</a></span></li><li><span><a href="#Discussion-and-Hypothesis" data-toc-modified-id="Discussion-and-Hypothesis-13.0.2">Discussion and Hypothesis</a></span></li></ul></li><li><span><a href="#3.1-When-do-people-tip-the-most-?" data-toc-modified-id="3.1-When-do-people-tip-the-most-?-13.1">3.1-When do people tip the most ?</a></span><ul class="toc-item"><li><span><a href="#3.1.1--Related-feature-with-phik's-correlation-(Tip-with-total_bill-and-table_size)" data-toc-modified-id="3.1.1--Related-feature-with-phik's-correlation-(Tip-with-total_bill-and-table_size)-13.1.1">3.1.1 -Related feature with phik's correlation (Tip with total_bill and table_size)</a></span></li><li><span><a href="#Conclusion-:" data-toc-modified-id="Conclusion-:-13.1.2">Conclusion :</a></span></li><li><span><a href="#3.1.2--Non-Related-feature-with-phik's-correlation-(Tip-with-eating_time,-week_end,-smoker-and-gender)" data-toc-modified-id="3.1.2--Non-Related-feature-with-phik's-correlation-(Tip-with-eating_time,-week_end,-smoker-and-gender)-13.1.3">3.1.2 -Non-Related feature with phik's correlation (Tip with eating_time, week_end, smoker and gender)</a></span></li><li><span><a href="#Interpetation-:" data-toc-modified-id="Interpetation-:-13.1.4">Interpetation :</a></span></li><li><span><a href="#Interpetation-:" data-toc-modified-id="Interpetation-:-13.1.5">Interpetation :</a></span></li></ul></li><li><span><a href="#Main-conclusion-:" data-toc-modified-id="Main-conclusion-:-13.2">Main conclusion :</a></span></li><li><span><a href="#3.2-When-are-the-table_size-the-largest-?" data-toc-modified-id="3.2-When-are-the-table_size-the-largest-?-13.3">3.2-When are the table_size the largest ?</a></span><ul class="toc-item"><li><span><a href="#3.2.1-Table_size-by-day/eating-time-and-gender" data-toc-modified-id="3.2.1-Table_size-by-day/eating-time-and-gender-13.3.1">3.2.1-Table_size by day/eating time and gender</a></span></li><li><span><a href="#Interpetation-:" data-toc-modified-id="Interpetation-:-13.3.2">Interpetation :</a></span></li><li><span><a href="#3.2.2-Table-size-by-gender-only" data-toc-modified-id="3.2.2-Table-size-by-gender-only-13.3.3">3.2.2-Table size by gender only</a></span></li><li><span><a href="#Interpetation-:" data-toc-modified-id="Interpetation-:-13.3.4">Interpetation :</a></span></li><li><span><a href="#3.2.3--Why-is-the-table_size-not-correlated-with-the-total_bill-on-the-phik_matrix" data-toc-modified-id="3.2.3--Why-is-the-table_size-not-correlated-with-the-total_bill-on-the-phik_matrix-13.3.5">3.2.3 -Why is the table_size not correlated with the total_bill on the phik_matrix</a></span></li></ul></li><li><span><a href="#Main-Conclusion-:" data-toc-modified-id="Main-Conclusion-:-13.4">Main Conclusion :</a></span></li><li><span><a href="#3.3--Total_bill" data-toc-modified-id="3.3--Total_bill-13.5">3.3- Total_bill</a></span><ul class="toc-item"><li><span><a href="#Let's-try-to-explain-why-the-gender-has-an-effect-on-total_bill-and-why-it-doesn't-affect-percentage" data-toc-modified-id="Let's-try-to-explain-why-the-gender-has-an-effect-on-total_bill-and-why-it-doesn't-affect-percentage-13.5.1">Let's try to explain why the gender has an effect on total_bill and why it doesn't affect percentage</a></span></li><li><span><a href="#3.3.1--Is-one-gender-favor-dinner-more-than-the-other-?" data-toc-modified-id="3.3.1--Is-one-gender-favor-dinner-more-than-the-other-?-13.5.2">3.3.1- Is one gender favor dinner more than the other ?</a></span></li><li><span><a href="#Interpetation-:" data-toc-modified-id="Interpetation-:-13.5.3">Interpetation :</a></span></li><li><span><a href="#3.3.2--Are-people-going-for-dinner-more-on-the-week-end-?" data-toc-modified-id="3.3.2--Are-people-going-for-dinner-more-on-the-week-end-?-13.5.4">3.3.2- Are people going for dinner more on the week-end ?</a></span></li><li><span><a href="#Interpetation-:" data-toc-modified-id="Interpetation-:-13.5.5">Interpetation :</a></span></li><li><span><a href="#3.3.3-Is-one-gender-has-a-tendency-to-go-out-more-on-the-week-end-?" data-toc-modified-id="3.3.3-Is-one-gender-has-a-tendency-to-go-out-more-on-the-week-end-?-13.5.6">3.3.3-Is one gender has a tendency to go out more on the week-end ?</a></span></li><li><span><a href="#Interpetation-:" data-toc-modified-id="Interpetation-:-13.5.7">Interpetation :</a></span></li></ul></li><li><span><a href="#Main-Conclusion-:" data-toc-modified-id="Main-Conclusion-:-13.6">Main Conclusion :</a></span></li></ul></li><li><span><a href="#Final-conclusion-:" data-toc-modified-id="Final-conclusion-:-14">Final conclusion :</a></span><ul class="toc-item"><li><span><a href="#Summary-:-Influence-on-tip" data-toc-modified-id="Summary-:-Influence-on-tip-14.1">Summary : Influence on tip</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Assignment 1 specification
#
# The purpose of this assignment is to use EDA on two of the datasets met in class.

# %% [markdown]
# ## Which datasets to consider?

# %%
import random

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns

import scipy.stats as stats
import statsmodels.api as sm
import pingouin as pg

import phik
from phik.report import plot_correlation_matrix
from phik import report

# Students should replace 12345678 with their student id (8-digit number, starting with 200)
myStudentId = 20101126

# Use myStudentId as the seed for the random number generator
random.seed(myStudentId)

dataSetToIgnore = random.choice(['Tips', 'Titanic', 'Algae'])
dataSetToIgnore
# Out:
# 'Algae'

# %% [markdown]
# Students should consider 2 sets from 'Tips', 'Titanic', 'Algae', ignoring the set that was randomly selected above.

# %% [markdown]
# ### Table of content :
#
#
# * Take me to .[Section A](#section_a)
# * Take me to [Section_B](#section_b)

# %% [markdown]
# ### <a name="section_b"></a>This is section b

# %% [markdown]
# ##Start of EDA 1##

# %% [markdown]
# # Task 1: First pass - load data set and initial clean

# %% [markdown]
# ##Start of Answer 1##

# %%
#Titanic, classification-predict whetere a passenger survived
#information rich text fields(Name, ticket number)
#predict passenger's survival chance 
#try to create new columns(transfort useless columns)

train = pd.read_csv("03-Titanic/train.csv")
print(train.shape)
train.head(25)

#-once finished import the test.csv and do the transformation on it +predict
#why source : module github -> Exploratory Data Analysis
# Out:
# (891, 12)
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
#
# ...

# %% [markdown]
# Data indications :
#
# Survived : 0 = Dead, 1=Yes
#
# pclass : 1st,2nd and 3rd class
#
# SibSp : number of siblings and spouse
#
# Parch : number of parents and childs
#
# Embarked : C = Cherbourg(France), Q= Queenstown(Ireland), S= Southampton(England)

# %% [markdown]
# ## Step 1 ideas :
#
# Info on df: Changing datatype : (Ideas where added/updated along the notebook)
#
# #-We could convert Sex or Embarked, to a category, but since their levels are not ordered there is no big advantage(but doesn't hurt)
#
# #-Convert Pclass to categorical and order it.(3 uniques values)
#
# #-We don’t want to convert Name, Ticket and Cabin since we want to perform further text processing on these columns. For example, extracting title (Capt, Mr, Miss, etc.) out of Name
#
# #-Maybe convert Cabin missing value to a boolean bcs it may tell us something(Not having a cabin's name may be due of Pclass, third/second class's cabin not registered)
#
# #-Cabin first letter may tell us something
#
# #-Location of cabin’s missing values are important (1st class passengers were most likely to have a cabin) so add new category level "Unknown".
#
# #-Replace Embarked’s 2 missing values with mode ("S", 644/891=72%).
# Note: Use df.Embarked.value_counts(dropna=False) to include missing values in count tables.
#
# #-The first letter of the cabin is actually the titanic's passergers deck, we will convert Cabin into Deck(cabin_area) and convert it into a categorical features
#
# #-In Titanic, feature Fare appears to have no missing values, but has 15 zero entries. Are these missing
# values? or free tickets due to age? . . .
#
# #-Fare distribution has large outliers and is skewed — remove/fix outliers and transform.
#
# #-Maybe drop Ticket Column
#
# #-What to do with age missing values ? (replacing with the median ?) We replaced it with the mean of their respecting Title's age
#
# -Maybe fuse SibSp and ParCh into family_size and transform it into a categorical values(order)
#
# #-Missing values after changing the Title resolve it
#
# #-Maybe a better solution for Fare amount instead of removing every values > Upper boundary
#
# #-Instead of removing the Fare outliners by using the IQR rule, we could create a new categorical features('Super_Cheap', Cheap', 'Modest,'Expansive') based on (<Q1, <median, <Q3 and <Max) of the Fare
#
# -For the KNN, we would need some mapping(See slides on Data-Handling -map reduce ?)

# %% [markdown]
# Shape of df :

# %%
train.shape
# Out:
# (891, 12)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# Nulls values

# %%
train.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# There are 177 values for Age and 687 values for Cain that are NaN

# %% [markdown]
# ###  1.1- Replacing Embarked missing values with .fillna('S')

# %%
train['Embarked'] = train['Embarked'].fillna("S")
#We replace by S because this is where most people embark 644/891=72%
train.Embarked.unique()
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %% [markdown]
# No more missing values for Embarked, we put S instead of NaN

# %% [markdown]
# ### 1.2- Add a new categories : Unknow for Cabin's location

# %% [markdown]
# 72% of cabin's location are missing, it may indicate something(a dead person or a 3rd class) so let's keep it and transform it into a boolean, we might also check what the first letter of a Cabin mean.
#
# With a little bit of research, the first letter of Cabin represent the deck.
#
# Apparently the titanic had 10 decks, 8 of them were passenger deck(our feature) from B to G + A for Promenade Deck and T for the Tank top

# %%
#Fill missing values by unknow
train['Cabin'] = train['Cabin'].fillna("Unknow")
#train.head(25)

#train.isna().sum()

# %% [markdown]
# Now that we don't have any missing values for Cabin ,let's **transform the Cabin to a categorical features with the deck_name and unknow**, we will fetch the first letter of the cabin to use as a deck label.

# %%
#Get the first letter of the cabin and create a new column Deck that will be Categorical
train['Deck'] = train['Cabin'].str[:1]
train.Deck = pd.Categorical(train.Deck, categories=['A', 'B', 'C', 'D','E','F','G','T','U'], ordered=False)


#Check if the data_type and name of Deck got updated correctly
#train.info()
#train.isna().sum()
#train.head()

# %% [markdown]
# Now we have the **categorical feature Deck** that will tell us some useful information for the target.
#
# Depending where the flood took place, the deck(cabin position) may be important(people taken by surprise), also we now have no more missing value, 'U' will represent a missing value (Not having a cabin's name may be due of Pclass, third/second class's cabin not registered)

# %% [markdown]
# ### 1.3-New categorical title column based on the name

# %% [markdown]
# From the dataset, we can see that the title always come in 2nd place with a capitalization on the first letter.
# Knowing the title of someone indicate his social status and thus be useful for the survived prediction.

# %%
train['Title'] = train['Name'].str.extract(' ([A-Za-z]+)\.', expand=False)
train.head(10)
#We can see that the new columns has been successfully added
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
#train['Title'].value_counts()

# %%
#quick example on the example of title : Did the captain of the ship sink with it ?
train.query("Title=='Capt'")
# Out:
#      PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 745          746         0       1  Crosby, Capt. Edward Gifford  male  70.0
#
#      SibSp  Parch     Ticket  Fare Cabin Embarked Deck Title
# 745      1      1  WE/P 5735  71.0   B22        S    B  Capt

# %% [markdown]
# The captain died with his ship :Survived = 0
#
# Now let's regroup some values and put them into categories

# %%
train['Title'] = train['Title'].replace(['Dona','Rev','Major','Col','Capt','Countess','Sir','Don','Jonkheer','Dr','Lady'], 'rare_title')
train['Title'] = train['Title'].replace('Mlle', 'Miss')
train['Title'] = train['Title'].replace('Ms', 'Miss')
train['Title'] = train['Title'].replace('Mme', 'Mrs')
#train['Title'].value_counts()

train.Title = pd.Categorical(train.Title, categories=['Master', 'Miss', 'Mr', 'Mrs','rare_title'], ordered=False)
train.Title.unique()
train['Title'].value_counts()
# Out:
# Mr            517
# Miss          185
# Mrs           126
# Master         40
# rare_title     23
# Name: Title, dtype: int64

# %%
#Check if train.Title is category
#train.info()
#train.head(50)
#train.isna().sum()

# %% [markdown]
# We now have **the categorical features Title that will be useful for our target (Children, Important_people, Man, Woman)**
# (Childrens and Woman first, is it true ?)

# %% [markdown]
# ### 1.4-Fare, 0 values treatments
#
# feature Fare appears to have no missing values, but has 15 zero entries. Are these missing
# values? or free tickets due to age?
#
# Let's look at the excel to see informations about that

# %%
#This part should be done before creating the Fare_range
train.query("Fare == 0")
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 179          180         0       3               Leonard, Mr. Lionel  male
# 263          264         0       1             Harrison, Mr. William  male
# 271          272         1       3      Tornquist, Mr. William Henry  male
# 277          278         0       2       Parkes, Mr. Francis "Frank"  male
# 302          303         0       3   Johnson, Mr. William Cahoone Jr  male
# 413          414         0       2    Cunningham, Mr. Alfred Fleming  male
# 466          467         0       2             Campbell, Mr. William  male
# 481          482         0       2  Frost, Mr. Anthony Wood "Archie"  male
# 597          598         0       3               Johnson, Mr. Alfred  male
# 633          634         0       1     Parr, Mr. William Henry Marsh  male
# 674          675         0       2        Watson, Mr. Ennis Hastings  male
# ...

# %% [markdown]
# As we can see, the hypothethis that these fares are free due to being children is false since Parch==0 for all of them, we can also note that they all come from different class(even a noble so would be surprinsing if boarded clandestinely).
#
# What we are going to do is to modify their Fare to their respecting Title Fare's mean.(So it will be more accurate and also permit to be classified in the good Fare_range(for the noble one))

# %%
#Let's see the respective means for Title
train.groupby('Title')['Fare'].mean()
#Mr.mean() : 24.44, rare_title.mean() : 37.17


#Replacing all the Mr with a value of 0
train['Fare'] = train['Fare'].replace(0, 24.44)

#Replacing the single noble
train.loc[train.PassengerId == 823,'Fare']=37.17

#Let's check if we still have Fare with 0 value
#train.query("Fare == 0")
#No more Fare value of 0

# %%
#Let's check if our noble with a Fare of 0 got the rare_title Fare's mean
train.query("PassengerId == 823")
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 822          823         0       1  Reuchlin, Jonkheer. John George  male
#
#       Age  SibSp  Parch Ticket   Fare   Cabin Embarked Deck       Title
# 822  38.0      0      0  19972  37.17  Unknow        S    U  rare_title

# %% [markdown]
# We **no longer have missing values for Fare**, it has been replaced by the mean of the corresponding Title's Fare

# %% [markdown]
# ### 1.5-Fare skewed/outliner need to remove and transform (Fare_range)
#
# Apparently the Fare has a lot of outliner and a skewed distribution, in order to not mess our survival prediction, we will do some cleaning/transformation.
#
# We will first use a histplot to see the distribution and a boxplot to better see the outliner:

# %%
sns.histplot(data=train, x="Fare",binwidth=10,kde=True)
plt.title("Distribution of Fare")
plt.show()

sns.boxplot(data=train, x="Fare")
plt.title("Boxplot of Fare")
# Out:
# Text(0.5, 1.0, 'Boxplot of Fare')

# %% [markdown]
# As we can see, the Fare is heavily skewed to the right(a lot of outliers to the left), contrary to the tip dataset, the titanic is larger so we can allow ourself to remove some outliers.
#
# It is worth pointing out that with the histplot and kde=True, if we remove the outliers, it will kind of ressemble a normal distribution.
#
# To remove the outliers, we will apply the IQR rule.

# %%
# IQR rule (IQR = Q3 — Q1)
#Lower and Upper boundaries : Q1–1.5 * IQR and Q1+1.5 * IQR

train[['Fare']].describe()
# Out:
#              Fare
# count  891.000000
# mean    32.629943
# std     49.525266
# min      4.012500
# 25%      7.925000
# 50%     15.100000
# 75%     31.137500
# max    512.329200

# %%
Q1 = train['Fare'].quantile(0.25)
Q3 = train['Fare'].quantile(0.75)

IQR = Q3 - Q1

Lower_boundary = Q1-1.5*IQR 
Upper_boundary = Q3+1.5*IQR
print("The Lower boundary is :", Lower_boundary)
print("The Upper boundary is :", Upper_boundary)
# Out:
# The Lower boundary is : -26.893749999999994
# The Upper boundary is : 65.95625

# %% [markdown]
# We won't need to use the Lower boudary, there is no bottom outliers, we will transform Fare to only take values under the Upper_boundary.
#
# This solution may be a little to drastic because we would be loosing a lot of Pclass : 1 data.

# %%
#train[['Fare']]  
trainFare = train.query("Fare < 65.61")
sns.histplot(data=trainFare, x="Fare",kde=True)
#trainFare.count()
#775 row
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='Count'>

# %%
#Getting the median value of outliners to remplace them in the new dataframe

trainFareUpper = train.query("Fare > 65.65")
UpperFareMedian = trainFareUpper['Fare'].median()

#train[train['Fare']<Lower_boundary]
# no values

# %% [markdown]
# I fell like doing it that way may not be very benificial for us...( we would loose to much values 891-775 = 116 )
# Instead we are going to turn Fare into a categorical feature and order it based on price range

# %%
#train['Fare_range']=0

train.loc[train['Fare']<=7.91, 'Fare_range'] = 'Super_cheap'
train.loc[(train['Fare']>7.91)&(train['Fare']<=14.454),'Fare_range']= 'Cheap'
train.loc[(train['Fare']>14.454)&(train['Fare']<=31),'Fare_range']= 'Modest'
train.loc[(train['Fare']>31)&(train['Fare']<=513),'Fare_range']= 'Expansive'

train.head()

train.Fare_range = pd.Categorical(train.Fare_range, categories=['Super_cheap', 'Cheap', 'Modest', 'Expansive'], ordered=False)
train.Fare_range.unique()
train.Fare_range.value_counts()
# Out:
# Modest         243
# Expansive      223
# Cheap          217
# Super_cheap    208
# Name: Fare_range, dtype: int64

# %% [markdown]
# Now that all the processing of Fare is done, let's check the proportion of Fare_range with a countplot.

# %%
sns.countplot(data=train, x="Fare_range")
plt.title("Distribution of Fare_range")
plt.show()

# %% [markdown]
# **There is no more outliners and Fare_range is categorical(in the later stage we will see if having a super_cheap or expansive ticket price matter**

# %% [markdown]
# ### 1.6-Age Missing values :
#
# There is 177 missing age values, we will fill it by the median of their respecting social class(Title)
#
# First we will the average age for each Ttile and then we are going to replace it with loc

# %%
#average age by title
train.groupby('Title')['Age'].mean()
# Out:
# Title
# Master         4.574167
# Miss          21.845638
# Mr            32.368090
# Mrs           35.788991
# rare_title    45.545455
# Name: Age, dtype: float64

# %% [markdown]
# One thing that I have missed until now is **that Master represent childrens**, It could be useful later to see if they have a higher survival rate(Childrens first)

# %%
#replacing null values of Age
train.loc[(train.Age.isnull())&(train.Title=='Master'),'Age']=5
train.loc[(train.Age.isnull())&(train.Title=='Miss'),'Age']=22
train.loc[(train.Age.isnull())&(train.Title=='Mr'),'Age']=33
train.loc[(train.Age.isnull())&(train.Title=='Mrs'),'Age']=36
train.loc[(train.Age.isnull())&(train.Title=='rare_title'),'Age']=46

# %%
train.info()
train.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        891 non-null    object
#  11  Embarked     891 non-null    object
#  12  Deck         891 non-null    category
#  13  Title        891 non-null    category
#  14  Fare_range   891 non-null    category
# dtypes: category(3), float64(2), int64(5), object(5)
# memory usage: 87.0+ KB
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# ...

# %% [markdown]
# **We no longer have any missing value for Age**, it has been replaced by their corresponding average Title's age

# %% [markdown]
# # Final touch

# %%
#Let's also change some data type to categorical Pclass, Embarked, Sex

#Pclass
train.Pclass = pd.Categorical(train.Pclass, categories=[1, 2, 3], ordered=True)
print(train.Pclass.unique())

#Embarked
train.Embarked.unique()
train.Embarked = pd.Categorical(train.Embarked)
print(train.Embarked.unique())

#Sex
train.Sex.unique()
train.Sex =pd.Categorical(train.Sex)
print(train.Sex.unique())


#Remove Ticket(too hard to work with), Fare(Fare_range is better for letter parts), Name(Title is better),
#PassengerId(Not useful), Cabin(Deck ->Cabin_area, easier to work with)

train.drop(columns=['Ticket', 'Fare', 'Name', 'PassengerId','Cabin'], inplace=True)
# Out:
# [3, 1, 2]
# Categories (3, int64): [1 < 2 < 3]
# ['S', 'C', 'Q']
# Categories (3, object): ['C', 'Q', 'S']
# ['male', 'female']
# Categories (2, object): ['female', 'male']

# %%
train.head()
# Out:
#    Survived Pclass     Sex   Age  SibSp  Parch Embarked Deck Title  \
# 0         0      3    male  22.0      1      0        S    U    Mr
# 1         1      1  female  38.0      1      0        C    C   Mrs
# 2         1      3  female  26.0      0      0        S    U  Miss
# 3         1      1  female  35.0      1      0        S    C   Mrs
# 4         0      3    male  35.0      0      0        S    U    Mr
#
#     Fare_range
# 0  Super_cheap
# 1    Expansive
# 2        Cheap
# 3    Expansive
# 4        Cheap

# %%
#saving our data
#train.to_csv('data/train.csv', index=False)

# %%
#Check if date type got updated
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Survived    891 non-null    int64
#  1   Pclass      891 non-null    category
#  2   Sex         891 non-null    category
#  3   Age         891 non-null    float64
#  4   SibSp       891 non-null    int64
#  5   Parch       891 non-null    int64
#  6   Embarked    891 non-null    category
#  7   Deck        891 non-null    category
#  8   Title       891 non-null    category
#  9   Fare_range  891 non-null    category
# dtypes: category(6), float64(1), int64(3)
# memory usage: 34.3 KB

# %%
train.describe()
# Out:
#               Age       SibSp       Parch
# count  891.000000  891.000000  891.000000
# mean    29.856532    0.523008    0.381594
# std     13.292134    1.102743    0.806057
# min      0.420000    0.000000    0.000000
# 25%     22.000000    0.000000    0.000000
# 50%     30.000000    0.000000    0.000000
# 75%     36.000000    1.000000    0.000000
# max     80.000000    8.000000    6.000000

# %% [markdown]
# **Now that we have finished to clean our data, we can move to the Task 2, we may make some additional operations for SibSb and Parch to merge them into a new categorical column : family_size**

# %% [markdown]
# ##End of Answer 1##

# %% [markdown]
# # Task 2: Second pass - individual features and target
#
# ### <a name="section_a"></a> This is section A

# %% [markdown]
# ##Start of Answer 2##

# %% [markdown]
# ## Task 2 ideas :
# Let's think about some ideas that may affect the survival rates(we may add more later)
#
# #-Survival quick peek
#
# -If you are in 1st class(richer- you are more likely to survive), or rather if you are in 3rd class you are more likely to die
#
# -Also see with the fare_range, should be in accordance with 1st class
#
# -Based on your deck(cabin placement) and where the flood started you may have less chances to survive(have to check that) + cabin Unknow
#
# -Based on sex/age (woman/children/elderly first evacuated)
#
# -If you had a family(SibSp or Parch) people may prioritize your survival
#
# -Based on the title we will see which are more likely to survive

# %% [markdown]
# **In total we have 9 features and 1 target :Survived(categorical). In this part we will group those features in 2(Categorical and Numerical features)**
#
# -We have 6 Categorical features (Pclass, Sex, Embarked, Deck, Title, Fare_range)
#
# -We have 3 Numericals (SibSp, Parch and Age)
#
# In the future we may change SibSp and Parch into categorical features or even merge them together into a commun feature that would represent family_size

# %% [markdown]
# # Target : Survived

# %% [markdown]
# First, let's take a lot at our target, what is the proportion of people who survived

# %%
#train.Survived.value_counts(normalize=True, dropna=False)
sns.countplot(x="Survived", data=train);
plt.title("Countplot of Survived")
train.Survived.count()
# Out:
# 891

# %%
train.loc[train.Survived == 1, ["Survived"]].count()
print("Around",np.ceil( (1-(342/891) )*100 ),"% of passengers died")
# Out:
# Around 62.0 % of passengers died

# %% [markdown]
# ### Interpretation :
#
# **There are more passengers that died than passaengers that surived**
#
# ## Global survival rate : 38%
# *May be useful to compare to this value(negative or positive effect)*

# %% [markdown]
# ### -------------------------------------Categorical features-------------------------------------

# %% [markdown]
# ### Pclass - 1st, 2nd and 3rd class
#
# Hypothesis : 1st class have a way higher chance at survival, followed up by 2nd class by a small margin. I would expect a big gap between 3rd class and 2nd class (because they are the 'worst' they would be prioritize in last)

# %%
#barplot for proportion and countplot for total
sns.barplot(x= train.Pclass, y =train.Survived)
plt.title("Barplot of chance of surivals based on Pclass")
plt.show()
sns.countplot(x = train.Pclass, hue=train.Survived)
plt.title("Countplot of people who survived based on Pclass")
train[['Pclass','Survived']].groupby('Pclass').mean().reset_index()
# Out:
#   Pclass  Survived
# 0      1  0.629630
# 1      2  0.472826
# 2      3  0.242363

# %% [markdown]
# ### Interpretation :
#
# **Based on these plot, we can clearly see that Pclass has an influence of Survived**. More than half of people in 1st class survived(63%) and almost 50% for people in 2nd class.
# People in 3rd class have a way lesser survival rate, barely 1 people out of 4 (24%)
#
# We can also clearly see with the Countplot that most people who died were in 3rd class, and by a lot.
#
# **The Pclass influence the survival rate**

# %% [markdown]
# ### Fare_range - Money and survival rates
#
# Hypothesis : The higher your Fare_range the most likely you will survive, we can except result that will match the Pclass

# %%
sns.barplot(x= train.Fare_range, y =train.Survived)
plt.title("Barplot of chance of surivals based on Money")
plt.show()
sns.countplot(x = train.Fare_range, hue=train.Survived)
plt.title("Countplot of people who survived based on Money")
train[['Fare_range','Survived']].groupby('Fare_range').mean().reset_index()
# Out:
#     Fare_range  Survived
# 0  Super_cheap  0.206731
# 1        Cheap  0.308756
# 2       Modest  0.423868
# 3    Expansive  0.578475

# %% [markdown]
# ### Interpretation :
# **We can see that when paying a higher fare(richer), you chance of surival are higher, it is the same interpretation as Pclass, the cheaper your fare, the more likely you are not going to survive**, people with a expansive ticket have more than 50% chance to survive whereas people with a Super_cheap one have only 20%
#
# **The fare_range influence the survival rate**

# %% [markdown]
# ### Title class - Do important people come first ?
#
# Hypothesis : The nobility would come first(not the same social standards as today), they the woman(Miss and Mrs), children(Master) and finally the men(Mr) but with a big gap(Mens are by far the most likely to die)

# %%
sns.barplot(x= train.Title, y =train.Survived)
plt.title("Barplot of chance of surivals based on Title")
plt.show()
sns.countplot(x = train.Title, hue=train.Survived)
plt.title("Countplot of people who survived based on Title")
train[['Title','Survived']].groupby('Title').mean().reset_index()
# Out:
#         Title  Survived
# 0      Master  0.575000
# 1        Miss  0.702703
# 2          Mr  0.156673
# 3         Mrs  0.793651
# 4  rare_title  0.347826

# %% [markdown]
# ### Interpretation :
# From these plot, there is a lot to discuss :
#
# -First **Mrs and Miss are the categories with the higher survival rate(79% and 70) with Mrs higher - It can be because she is married, Mrs has children to take care of**.
#
# -**Master(childrens) are next with a 57% survival rate, we would have expected to be closer to Miss and Mrs(Childrens and Womans first) but it may be caused that childrens are less capable than adult(swimming or panicking)**
#
# -Rare_title represent people with a unique position, nobility(Countesse for example) or doctors. **It is expected that their survival rates would be higher than the average person. Which is interesting because their survival rate is only at 34%. If look globaly the average survival rate was at 38% ! It is higher than the rare_title.**
# One explanation is that rare_title include some positions that will put everyone else first before them(ex :Major, Colonel , Captain) therefore it will bring the average towards the bottom.
#
# -**We might ask ourself if it would not be better for our trainning model to split rare_title into 2groups :**
#
#     -Nobility and doctors... , title that would most likely guarantes your survival
#
#     -Soldiers and ship's captain and aid...(position that would require you to prioritize others)
#
# -Finally there is **the Mr category with a survival rate of 15%, as expected it is the lowest by far.**
#
# **The Title influence the survival rate**

# %% [markdown]
# ### Deck - Position of cabin relative to flood + Unknow(missing values)
#
# Hypothesis : The Deck is derived from the Cabin, therefore it is linked to the Fare_price and Pclass and expect some similar results(deck corresponding to a specific Pclass).
#
# We can also guess that the category U will have the lowest survival rate(Unknow) because their cabin's number was missing(a 1st class customers or 2nd class is less likely to have his cabin's number missing). I would also expect another deck with a low survival rate(the first one to be touched)

# %%
sns.barplot(x= train.Deck, y =train.Survived)
plt.title("Barplot of chance of surivals based on Deck")
plt.show()
sns.countplot(x = train.Deck, hue=train.Survived)
plt.title("Countplot of people who survived based on Deck")
train[['Deck','Survived']].groupby('Deck').mean().reset_index()
# Out:
#   Deck  Survived
# 0    A  0.466667
# 1    B  0.744681
# 2    C  0.593220
# 3    D  0.757576
# 4    E  0.750000
# 5    F  0.615385
# 6    G  0.500000
# 7    T  0.000000
# 8    U  0.299854

# %% [markdown]
# ### Interpretation :
#
# The deck feature is quite interesting because it raises some questions :
#
# -The **Deck B,D and E have a 75% survival rate which is enormus considering it doesn't include gender/children filtering , we may check if it's note because they are deck for 1st class people(with an expansive Fare_amount) or simply because their area where the one to sink last(the ship tilt in one way giving more chance to the others side) while still having enough boats**( the main reason that were so much casualties was because there was not enough emergency-boat)
#
# -From these plot we can also confirm our hypothesis that having a **missing cabin's name is negatively related to the survival rate (people dies way more often and way more when their cabin's name is missing** compared to others deck)
#
# -The other lowest survival chance come from the A deck, a 46% chance of survival but not too much of a gap with the 3rd lowest value(only 4% difference with G). But the countplot is way more interesting, when we compare it with others deck we can see that it is quite populated compared with G, we can try to google it to see if the A deck was touched first during the flood
#
# -On the same Idea, we can see that the C deck seems to be the most populated one, with a not to high survival rate, it may indicate that it was the last deck and people died because there was no more lifeboats left.
#
# Let's google it and confirm it

# %% [markdown]
# ![Olympic_&_Titanic_cutaway_diagram.png](attachment:Olympic_&_Titanic_cutaway_diagram.png)

# %% [markdown]
# A little bit of commenting :
#
# As we can see the titanic deck were build in a descending order(A being the Upper deck)
#
# -So I was wrong to assumed that A was touched first(it's the Upper deck promenade deck so unlikely), the other deck that I mentionned was the C deck which is also towards to top. deck D and E are in the middle and have one of the highest survival rate. G also had a low survival rate and it's on the bottom so it probably sank first.
#
# **But anyway the deck position have an influence with the survival rate and not having a cabin's number**

# %% [markdown]
# ### Embarked - Does the city you come from matters?(different countries)
#
# Hypothesis : Maybe if one city is richer or more developed than the others, the people there would be on average more rich and therefore have a higher survival rate, the reverse process could also be true.

# %%
sns.barplot(x= train.Embarked, y =train.Survived)
plt.title("Barplot of chance of surivals based on Embarked")
plt.show()
sns.countplot(x = train.Embarked, hue=train.Survived)
plt.title("Countplot of people who survived based on Embarked")
train[['Embarked','Survived']].groupby('Embarked').mean().reset_index()
# Out:
#   Embarked  Survived
# 0        C  0.553571
# 1        Q  0.389610
# 2        S  0.336957

# %% [markdown]
# ### Interpretation :
# -People that come from **Cherboug have a higher chance to survive, we may check the proportion of Fare_range in this city and compare it to the others( Are people from there paying more on their ticket on average?)**
#
# -Southampton(England) is the lowest survival rate, it is also where most passengers are from(start of voyage). Because it is the lowest value, we will also see the average Fare_range for this city
#
# -Queenstown was the last stop(in Ireland) and with the lowest amount of people.
#
# -**The Embarking probably influence the survival rate indirectly**

# %% [markdown]
# ### Sex - Woman first ?
# As we saw in the Title section, we expect woman to have a way higher survival rate than mens.

# %%
sns.barplot(x= train.Sex, y =train.Survived)
plt.title("Barplot of chance of surivals based on Sex")
plt.show()
train[['Sex','Survived']].groupby('Sex').mean().reset_index()
#train.query("Sex=='female'").count()
#314 Females
#train.query("Sex=='male'").count()
#577 Males
# Out:
#       Sex  Survived
# 0  female  0.742038
# 1    male  0.188908

# %% [markdown]
# ### Interpretation
# -**Those plots confirm our theory, woman have almost 4 times more chance to survive than mens.**
#
# -We can also note that there is more mens than females(577 againts 314)
#
# **The Sex influence the survival rate**

# %% [markdown]
# ### -------------------------------------Numerical features-------------------------------------

# %% [markdown]
# **In reality Age is the only countinuous variable, SibSp and Parch are discrete variables with few possibilities, they can be treated as categorical variables(better)**
#
# *We can even change Age into a categorical variable or map it for the KNN by using the same method we used to create Fare_range*

# %% [markdown]
# ### 2.2.1 - Age - Childrens, Adult and Elderly
# Hypothesis : Below an certain age, the survival rate will increase, will it be the same for the elderly? (at a certain age they will be prioritized), will it be a reverse bell distrubution ?
# We will make an kde plot to see the distribution, we will also plot a violinplot because a kde plot may have some distorsions and it will highlight the difference between Survived or not

# %%
sns.kdeplot(data=train, x="Age", hue="Survived")
plt.title("KDEplot of surviving or not by age")
plt.show()
sns.violinplot(data=train, x="Survived", y="Age")
plt.title("violinplot of surviving or not by age")
plt.show()
sns.kdeplot(data=train, x="Age", hue="Survived")
plt.title("KDEplot of surviving or not by age centered on 10")
plt.xlim(0, 20)


#train[["Age", "Survived"]].corr()
#r = -0.09, not to useful(we look at Age as a whole)
# Out:
# (0.0, 20.0)

# %% [markdown]
# ### Interpretation :
#
# In the kde plot, what we are looking for is the gap between the blue and orange line(survived or not).
#
# Be careful in the interpretation, more people between 10-40 age range survived(count) but their chance of survival are actually the lowest(biggest gap between the orange and blue line)
#
# **We can see that below the age of 10 approximately, your chance of survival are higher than your chance of dying**, this is especially highlighted on the violin plot and 2nd kdeplot. That means that being a teenager/adolescent doesn't help you
#
# **Being an elder do bring up your chance of survival but not by much.Rather we can interpret it that way : being between 10 and around 40 lower you chance of survival by quite a lot**
#
# We may plot an additional plot with appropriate limits for youger people
#
# Age seems to follow a normal distribution
#
# **The age influence the survival rate**

# %% [markdown]
# ### 2.2.2 - SibSp -Siblings and Spouse
# Hypothesis : Having a spouse may bring up your chance of survival, because females in general have a higher chance of survival, being associated with one may be beneficial. About the numbers of siblings it may bring up the variance ? brothers and sisters dying together or living together

# %%
sns.barplot(x= train.SibSp, y =train.Survived)
plt.title("Barplot of Survival rate based on SibSp")
train[['SibSp','Survived']].groupby('SibSp').mean().reset_index()
# Out:
#    SibSp  Survived
# 0      0  0.345395
# 1      1  0.535885
# 2      2  0.464286
# 3      3  0.250000
# 4      4  0.166667
# 5      5  0.000000
# 6      8  0.000000

# %% [markdown]
# ### Interpretation :
# From this barplot we can tell that :
#
# -**Not having any siblings or spouse slightly bring down your chance of survival**, for 0 SibSp : Survived's mean = 34%, and the global survival mean = 38%
#
# -**Having 1 or 2 SibSp increase your chances of survival(confirm our hypothesis)**
#
# -**Having more than that actually lower your chance of survival on average(25% for 3 and 16% for 4, even more than that and there is 0% chance of survival-> family dying together)**. Maybe in tense situation, bigger group start to fight more easily, plus it's surely harder to move around in a bigger group
#
# **The number of SibSp influence the survival rate**

# %% [markdown]
# ### 2.2.3 - Parch - Parents and Childrens
# Hypothesis : As we have seen before being in a small group is beneficial but being in a larger group is detrimental. The childrens may slow you down because you have to take care of them. Maybe because childrens are prioritize, being associated with childrens is good(generally you won't let a child alone on purpose)

# %%
sns.barplot(x= train.Parch, y =train.Survived)
plt.title("Barplot of Survival rate based on Parch")
train[['Parch','Survived']].groupby('Parch').mean().reset_index()
# Out:
#    Parch  Survived
# 0      0  0.343658
# 1      1  0.550847
# 2      2  0.500000
# 3      3  0.600000
# 4      4  0.000000
# 5      5  0.200000
# 6      6  0.000000

# %% [markdown]
# ### Interpretation :
# As expected we got pretty similar result to SibSp :
#
# -**This time having 1 to 3 Parch increase your survival rate but no more than that**(maybe 3 because 2parents and 1 child or 1 parents(surely mother) and 2 child)
#
# -**Having no Parch lower your chance of survival by roughly the same amount as not having any SibSp**
#
# -**Having "too much" Parch is detrimental for the survival rates**(you have to take care of your child)
#
# **The number of Parch influence the survival rate**

# %% [markdown]
# # Task 2 Conclusion :
#
# -**Being wealthy(Pclass, Fare_range) generally increase your chance of survival.**
#
# -**Your cabin placement(Deck) also has an influence on your chance of survival(Deck B,D,E preferably)** in the task3 let's see if these deck are linked to wealth.
#
# -**Your social status matters(Title), being a noble or the ship's captain drasticaly influence your chance of survival("the captain sink with his ship")**. Maybe do some more feature engineering.
#     -**Mrs have the highest chance to survive**
#     -**Then closely followed by Miss, not so far by Masters(Children) then by rare_title.**
#     -**Finally there is a big gap and Mr have a very low chance to survive.**
#
# -Based on where you embarked, your survival rates changes, **people that come from Cherboug have a higher chance to survive, (more than 50%) whereas people that come from Southampton have an lower chance to survive(34%)** than the global surviving chance(38%), most passengers are from Southampton. In task 3 we may plot Fare_range and Embarked to see if there is a reason.
#
# -Has discussed before, **on average Females have a way higher survival chance than Males.**
#
# -For the Age, while **being under 10 actually increase by quite a lot your survival chance(more than 50%)** being a teenager/adolescent don't help at all(**The 10-40 age range is where your chance of survival are the lowest**), being an **elder also increase your survival chance.**
#
# -For the **SibSp having 1 or 2 SibSp increase your survival chance**, not having any slightly decrease your survival chance, **having more than 2 decrease your survival chance and having more than 4 dramatically decrease your survival chance.**
#
# -The Parch was pretty much the same, **having 1 to 3 was beneficial, 0 slighly detrimental and more than 3 very bad for your survival chance.**
#
#
#
# **Before going into task 3 we may do a little more of data engineering, these would not matter much for EDA because the idea stay the same but if we want to improve the KNN accuracy we should do it(if we have time) **
#
# -Merging SibSp and Parch into a categorical feature(family_size) since both of these features kinda have the same relationship with Survived
#
# -Transforming age into Age_range, a categorical value with threshold(Child,Adult,Old) for it to be easier to work with
#
# -Maybe spliting Title.rare_title in to 2 categories, one which has Title that guarantes a very high survival chance and the oner which has Title that will tend to decrease the survival_rate

# %% [markdown]
# ##End of Answer 2##

# %% [markdown]
# # Task 3: Third pass - relationships between features and target

# %% [markdown]
# ##Start of Answer 3##

# %% [markdown]
# ### Task 3 ideas :
#
# #-Make the phik_matrix
#
# -pearson's or spearman's correlation
#
# #-We will merge SibSp and Parch into family_size to make it easier to work with
#
# ----------Money impacted
# #-fare_range/Pclass/Title/Deck with survived -how do these features together influence the survival rate.
#
# #-Also see how these features influence each other's
#
# #->Hypothesis fare_range influence your Pclass that influence your deck(cabin area)
#
# #-Deck, relation with fare_range and Pclass(phik_coefficient)
#
# #-Embarked and Fare_range(richer city ?) could also be gender related(maybe more woman are in cherboug therefore pulling the surival rate to the top)
#
# -----------Morals impacted
# #-Sex againts Title with Survival- Does Status wins againts morals ?(Already done in part 2, title include Miss and Mrs)
#
# #-Age againts Title with Survival- Does Status wins againts morals ?
#
# #-Family_size/gender with Survived, do we save family with only the mother or with the 2 parents
#
#
#
# #-When are the chance of survival the highest ? Scraped idea, during the study we already encountered group with a 100% chance of survival when crossing some features
#
# Hypothesis : (Female with a rare_title going of Cherbourg in 1st class with a high fare_range, comming from deck B,D or E) also include gender(elderly : age > 40 or child : age<10) with no more than 3 relatives(family_size =4) +maybe not with a rare_title but with the Mrs title(being married/having 1 child)
#
#
#
# --Scatterplot with bubles Represent multiple categorical variables in terms of 2 numerical variables(fare_range,Pclass,Sex ...)? with Age
#
# -Facetgrid with survived on y-axis
#
# -grouped violinplot 2categorical(survived would be the hue) + 1 numeric(age or Family_size)
#
# -Pairplot?(no more numeric values, only Age)
#
# -Point plots(multiples categorical values) a better alternative than barplot(will show the mean and not the count)

# %% [markdown]
# ## 2.3.0 - A little bit of data engineering -family_size

# %% [markdown]
# **Merging SibSp and Parch into the new categorical features Family_size :**

# %%
#df['W_Mark'] = df.Weight * df.Mark // 100
train['Family_size'] = train.SibSp + train.Parch +1
#We have too add +1 because it will include the interested passenger
train.Family_size.unique()
train.Family_size = pd.Categorical(train.Family_size, categories=[1,2,3,4,5,6,7,8,11], ordered=True)

# %%
#train.info()
train.Family_size.value_counts()
#train.head(20) worked
# Out:
# 1     537
# 2     161
# 3     102
# 4      29
# 6      22
# 5      15
# 7      12
# 11      7
# 8       6
# Name: Family_size, dtype: int64

# %% [markdown]
# Let's see if it follow the same rule of survival as Parch/SibSp, if yes, we are going to drop these columns

# %%
sns.barplot(data = train, x= "Family_size", y ="Survived")
plt.title("Barplot of Survival rate based on Family_size")
plt.show()
train[['Family_size','Survived']].groupby('Family_size').mean().reset_index()
#A family size of 0 don't make sense, there is atleast the passenger, we have to put +1
# Out:
#   Family_size  Survived
# 0           1  0.303538
# 1           2  0.552795
# 2           3  0.578431
# 3           4  0.724138
# 4           5  0.200000
# 5           6  0.136364
# 6           7  0.333333
# 7           8  0.000000
# 8          11  0.000000

# %% [markdown]
# ### Interpretation :
# It does follow the same principle of Parch and SibSb(having a few is good but too much is detrimental), but with some change, **not having any family members is detrimental, when you are alone your average survived rate would be 30% but the global survival rate is 38%.**
# **This time the average survival rate grow until 4 members(like Parch but with +1), it grow quite a lot because it reach 72%**
# **After that, the survival rate drop by quite a lot(a family_size of 5 or more members become bad)**
#
# Since it follow the same principle and therefore the same interpretation as SibSb and Parch(Families are saved first, but being in a family who is too big is bad surely because it's harder to move around, harder keep everything under control, harder to not panic or taking care of childrens)
# We can drop SibSp and Parch

# %%
#train.drop(columns=['SibSp', 'Parch'], inplace=True)
#train.columns
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'Age', 'Embarked', 'Deck', 'Title',
#        'Fare_range', 'Family_size'],
#       dtype='object')

# %% [markdown]
# ### Phik_matrix

# %%
train_phik = train[['Survived','Pclass', 'Fare_range', 'Title', 'Deck', 'Embarked','Sex','Age','Family_size']]

phik_overview = train_phik.phik_matrix()
phik_overview.round(2)

#from https://towardsdatascience.com/phik-k-get-familiar-with-the-latest-correlation-coefficient-9ba0032b37e7
plot_correlation_matrix(phik_overview.values, 
                        x_labels=phik_overview.columns, 
                        y_labels=phik_overview.index, 
                        vmin=0, vmax=1, color_map="Greens", 
                        title=r"correlation $\phi_K$", 
                        fontsize_factor=1.5, 
                        figsize=(10, 8))
plt.tight_layout()
# Out:
# interval columns not set, guessing: ['Survived', 'Age']

# %% [markdown]
# ### Intrpretation :
#
# A phik-matrix souded like a good idea because there is so many categorical variables and phik is better than pearson's coefficient for that. But here, this phik-matrix may not be as interesting as in Tips(in Tips we were looking for tip, table_size and total_bill so having an overview was very useful).
#
# **Here we are only looking for Survived so this much information may be a little bit daunting.**
#
# Also I am not too confortable with how the phik_matrix work but I feel like it fails to capture some interesting metrics :
#
# -For example the Age only has a coefficient of 0.21 but we know that depending on your age range, it matters quite a lot.
#
# -The Pclass if also surprinsingly low(Didn't catch the survival difference between first and third class ?)
#
# -Same for Family_size, Embarked and Deck.
#
# -It did give a good result on Sex and an acceptable one on Title/Fare_range ?
#
# *My guess is that the phik_matrix fails to catch interesting metrics when there is more than 2 possibles outcomes in a categorical features that is non-ordered (In tips it failed to capture the difference when day had 4 possibles values, but it worked fine when we changed it into week_end with only 2 possible values)*
#
# Thus we won't be using much the phik_matrix(compared to Tips)

# %% [markdown]
# ## 2.3.1.1 - Money related features impact on Survival rates
#
# -We will make 2 grid plot, one that will represent the proportion of survival rates, and a second one that will represent the count(how do some features favors each other)

# %%
grid = sns.FacetGrid(data = train, col='Pclass', row='Fare_range')
grid.map(sns.pointplot, 'Title', 'Survived')
plt.title("Survival rate based on Fare_range, Pclass and Title",x=0, y=4.60)

#We could add Deck as hue but it will decrease the readability, let's work on this feature later
# Out:
# D:\Anaconda\lib\site-packages\seaborn\axisgrid.py:670: UserWarning: Using the pointplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# Text(0, 4.6, 'Survival rate based on Fare_range, Pclass and Title')

# %% [markdown]
# ### Interpretation :
#
# There is a quite a lot to unpack :
#
# -First thing to note, there are some pointplot with no values, we will dive into that in the next section where we will use a countplot to see how features interatch with each others, for now **the focus is how features paired together interact with the survival rate**
#
# -The cheaper fare_range are represent towards to top(Super_cheap is on the top of the graph and Expansive on the bottom), the lower Pclass towards the left(Pclass: 1 is in the far right and Pclass: 3 is in the far left). The x-axis represent the different title(not ordoned) and the y-axis the survival rate
#
# -There is no (a few) values in the top-section of the grid, it makes sense because generally, 1st class ticket are expansive.Surprisingly, the reverse is not true, there are some values in the bottom-left grid(expansive ticket in class 3)
#
# -**The survival chance for a Expansive ticket/Pclass=3 are quite low for all Title**, one interesting thing is that the Mr title is the one with the highest survival rate here.(**In could mean that in Expansive ticket/class 3, it was the survival of the fitest/stronger, child and females have a very low chances of survival here**)
# In pclass= 3 (**even if you paid a lot, if you are in the 3rd class, you are likely to die**)
#
# -**In general being in class 3 means that it is more likely that will die(apart for the Mr when you have an expansive ticket or being a child with a cheap ticket)**
#
# -**Miss and Mrs are very likely to survive in class 1, 2(with any Fare_range) and surprisingly only if you have a super_cheap ticket in class3**
#
# -**Man in 1st class are more likely to survive compared to others Mr in others class for every fare_range**
#
# -**All people in 2nd class who have a rare_title died**(Hypothesis : there were soldiers/man of duty)
#
# -**We could expect that being in class 1 and having a rare_title would means a survival rate close to 1(Important people) but it is more around the 50% mark behind Master(Child), Miss and Mrs)**
#
# -**Childrens(Master) will always survive except if they are in 3rd class with a Modest/Expansive fare_range**
#
# -**We could have expected Mr in 2nd class to have higher survival rate than Mr in 3rd class but it is the same(very low) or even worse**(for class 3 and expansive ticket)

# %%
grid = sns.FacetGrid(data = train, col='Pclass', row='Fare_range')
grid.map(sns.countplot, 'Title')
plt.title("Proportion of each features based on Fare_range, Pclass and Title",x=-0.5, y=4.80)
# Out:
# D:\Anaconda\lib\site-packages\seaborn\axisgrid.py:670: UserWarning: Using the countplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# Text(-0.5, 4.8, 'Proportion of each features based on Fare_range, Pclass and Title')

# %% [markdown]
# ### Interpretation :
#
# -Most passengers are in 3rd class. Most passengers are men(by a lot) rare_tile and childrens(masters) are a minority.
#
# -Mr in 3rd class with a cheap_ticket represented the most commun pairing.
#
# -Most passengers in 1st class paid an expansive ticket(fare_range) followed by a modest ticket but there is no one with a cheap ticket in 1st and a very few with a super_cheap one (Fare_range correlated with Pclass)
#
# -There is no rare_title in 3rd class.
#
# -People in second class mostly bought a Modest or Cheap Ticket
#
# **Pclass and fare_range are correlated , no obvious correlation with Title(apart from rare_title but it's a minority)**
#
# *In accordance with the phik_matrix at the start of part3*

# %%
#corr = train[["Fare_range","Pclass"]].phik_matrix()
#corr

# %% [markdown]
# ### 2.3.1.2 - Deck with other's features
# ->Hypothesis fare_range influence your Pclass that influence your deck(cabin area).
#
# We already know that fare_range influence Pclass, let's see how Pclass influence Deck(countplot : verify that certain deck are assigned to a certain class)
#
# See the relation between Deck, Pclass and Survived
#
# -Deck, relation with fare_range and Pclass(phik_coefficient)

# %%
#grid = sns.FacetGrid(data = train, row='Pclass', col='Fare_range')
#grid.map(sns.histplot, 'Deck')
#plt.show()

sns.countplot(data=train,x="Deck",hue="Pclass")
plt.title("Number of cabin by Deck and Pclass")
plt.show()

sns.barplot(data=train, x="Survived", y="Deck", hue="Pclass", dodge=True,errwidth=0.5)
plt.title("Survival chance based on Deck and Pclass")
# Out:
# Text(0.5, 1.0, 'Survival chance based on Deck and Pclass')

# %% [markdown]
# ### Interpretation :
# With the barplot, **we can conclude that the deck is correlated with the Pclass**, deck A, B, C ,D and E are moostly reserved for the 1st class, it is **important to note that there is a lot of Unknow cabin(a lot of 2nd class and a awful lot of 3rd class) so this representation is biaised.**
#
# With the barplot we can see confirm again that the deck has an influence with the survival rate, **people in 3rd class in the E deck mostly survive. If we cross it with the countplot one hypothesis would be that because there were so few, the higher class showed charity and prioritized them.**
#
# Another possible interesting interpretation is that we know that **having a cabin's name missing lower your survival rate, but paired with the Pclass, it is not the lowest value ! It's actually the passengers in 3rd class in the F deck.** Again if we compare with the countplot, there is only 2nd class and 3rd passengers with the 2nd class being the majority. **What could have happened is that the 2nd class people prioritized themself first and left the 3rd classers at their own demise.**
#
# *Deck being strongly correlated with the Pclass agrees with the phik_matrix, it is also by default correlated with the fare_range since it is correlated with the Pclass. Deck being a little correlated with Survived also kinda join our interpretaion*

# %% [markdown]
# ### 2.3.1.3 -  Embarked with other's features
# Embarked and Fare_range(richer city ?) could also be gender related.(maybe more woman are in cherboug therefore pulling the surival rate to the top). Or Family_size
#
# ->We will use countplots with each features suceptibles to increase the survival chance(We won't plot deck because it is strongly correlated with Pclass)
#
# Why one city has a way higher chance of survival than the other 2 ?

# %%
features=["Fare_range","Pclass","Sex","Family_size"]

for f in features:
    sns.countplot(data=train,x="Embarked",hue=f)
    plt.title("Countplot of Embarked by "+str(f))
    plt.show()

# %% [markdown]
# ### Interpretation :
#
# These plot can explain why the survival rate is high in Cherbourg and low in Southampton
#
# -We know that in general, having a more expansive ticket(Modes/Expansive) increase the chance of survival compared to a Cheap/Super_cheap ticket. **Cherbourg have a way bigger proportion of passengers with a Modest/Expansive ticket compared to the others two.**
#
# -**There are way more people in first class in Cherbourg than in the other 2 cities**(as expected since correlated with fare_amount) therefore bringing up the survival rate for Cherbourg
#
# -Female are more likely to survive, **Queenstown has the larger female proportion compared to the other two, closely followed but Cherbourg, Southampton have way higher Male than female(=bad)**
#
# -Again **family_size play in favor for Cherbourg, it is the city that has the best proportion of passenger with a family size between 2 and 4 threfore** bringing up the survival rate for Cherbourg. Southampton has a the most passengers with a family_size greater than 4(=bad) and also the highlest proportion of single passenger(=bad)
#
# **The reason why the survival rate is higher in Cherbourg is because of these factors that favors the survival rate. The reverse can be said for Southampton. Certains city indirectly interact with the survival rate**

# %%
#train.groupby(['Embarked','Pclass'])['Survived'].agg(["min","max", "mean", "count", "std"])

#df.groupby(['sex','eating_time','day'])['table_size'].agg(["min","max", "mean", "count", "std"])
# Out:
#   Embarked  Survived
# 0        C  0.553571
# 1        Q  0.389610
# 2        S  0.339009

# %% [markdown]
# ## 2.3.2 - Morality related features, impact on Survival rates
#
# #-Sex againts Title with Survival- Does Status wins againts morals ?(Already done in part 2, title include Miss and Mrs)
#
# -Age againts Title with Survival- Does Status wins againts morals ?
#
#
# -Family_size/gender with Survived, do we save family with only the mother or with the 2 parents
#
# -Age and Title corrolated with the phik_matrix, why ? It raises some questions, do elderly die less than adult because of good-will or because something else

# %% [markdown]
# ### 2.3.2.1 -Age againts Title - Do we save children and elderly first or important_people ?
#
# We are going to look at the average survival rate of rare_people and the average_survival rate of passengers under 10 and greater than 65 and then compare

# %%
#train[['Title','Survived']].groupby('Title').mean()
#train.loc[train.Title=="rare_title",['Survived']].mean()
print("The average survival chance of someone with a rare_title(important) are",round(train.query("Title=='rare_title'").Survived.mean()*100),"%")
print("The average survival chance of passengers younger than 10 years old are",round(train.query("Age <=10").Survived.mean()*100),"%")
print("The average survival chance of passengers older than 60 years old are",round(train.query("Age >= 60").Survived.mean()*100),"%")
# Out:
# The average survival chance of someone with a rare_title(important) are 35 %
# The average survival chance of passengers younger than 10 years old are 59 %
# The average survival chance of passengers older than 60 years old are 27 %

# %% [markdown]
# ### Interpretation :
#
# **We prioritize children to important people, but we don't prioritize important people rather than elderly.**
# This interpretation may be biaised because we can think that most people with a unique title are healthy and can save themself, but it is not necessarely true for children or elderly people.
# We cannot conclude that status completely win againts moral(not a huge difference and there may be some others factors).

# %% [markdown]
# ### 2.3.2.2 - Do passengers family dies together ? Or do they split them ?

# %%
train.groupby(['Family_size','Sex'])['Survived'].agg(["min","max", "mean", "count", "std"])
# Out:
#                     min  max      mean  count       std
# Family_size Sex
# 1           female    0    1  0.785714    126  0.411964
#             male      0    1  0.155718    411  0.363029
# 2           female    0    1  0.816092     87  0.389655
#             male      0    1  0.243243     74  0.431969
# 3           female    0    1  0.775510     49  0.421570
#             male      0    1  0.396226     53  0.493793
# 4           female    0    1  0.842105     19  0.374634
#             male      0    1  0.500000     10  0.527046
# 5           female    0    1  0.250000     12  0.452267
#             male      0    0  0.000000      3  0.000000
# 6           female    0    1  0.375000      8  0.517549
#             male      0    0  0.000000     14  0.000000
# 7           female    0    1  0.375000      8  0.517549
#             male      0    1  0.250000      4  0.500000
# 8           female    0    0  0.000000      2  0.000000
# ...

# %% [markdown]
# ### Interpretation :
# **By the look of it, even if the family_size is greater than 2, males still die considerably more than females, that means that the titanic has mode a lot of widows and single-raised child.**

# %% [markdown]
# ## Main conclusion :
#
# In order to increase our chance of survivability in the Titanic, it helps to :
#
# -Being Female
# -Mrs or Miss title than Masters and then rare_title
# -Departure from Cherbourg then Queenstown and finally Southampton
# -Being in 1st class with a high fare_range(the less expansive/ less class-the less change your survival rate)
# -Being in the deck B,D or E
# -Being younger than 10 and older than 40(for Males particularely)
# -Having some relatives(family_size =4) (being married/having 1 child)

# %% [markdown]
# ##End of Answer 3##

# %% [markdown]
# ##End of EDA 1##

# %% [markdown]
# ##Start of EDA 2##

# %% [markdown]
# # Task 1: First pass - load data set and initial clean

# %% [markdown]
# ##Start of Answer 1##

# %%
#No target column
#How do factors influence others, seethe slides
#df.info()
df = pd.read_csv('01-Tips/tips.csv')
print("Data shape :",df.shape)

#Add tip percentage
df['tip_percentage'] = df['tip']/df['total_bill']*100

#Fix Data Types
df.sex = pd.Categorical(df.sex)
df.sex.unique()

df.day = pd.Categorical(df.day, categories=['Thur', 'Fri', 'Sun', 'Sat'], ordered=True) #no service on Monday and Tuesday
df.day.unique()

df.smoker = pd.Categorical(df.smoker)
df.smoker.unique()

df.eating_time = pd.Categorical(df.eating_time, categories=['Lunch', 'Dinner'], ordered=False)
df.eating_time.unique()

#Let's also rename time as eating_time and size as table_size to avoid confusion and conflict with .size
df.rename(columns={"time": "eating_time","size":"table_size"},inplace=True)
print("\nData type :")
df.info()
#Check for missing values
print("\nIs there missing values ?")
df.isna().sum()
# Out:
# Data shape : (244, 8)
#
# Data type :
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   total_bill      244 non-null    float64
#  1   tip             244 non-null    float64
#  2   sex             244 non-null    category
#  3   smoker          244 non-null    category
#  4   day             244 non-null    category
#  5   eating_time     244 non-null    category
#  6   table_size      244 non-null    int64
#  7   tip_percentage  244 non-null    float64
# dtypes: category(4), float64(3), int64(1)
# memory usage: 9.3 KB
#
# Is there missing values ?
# total_bill        0
# tip               0
# sex               0
# smoker            0
# day               0
# eating_time       0
# table_size        0
# tip_percentage    0
# dtype: int64

# %%
#saving
df.to_csv('01-Tips/tips.csv', index=False)

# %%
#Function to calculate the percentage increase between 2 categorical values

def percentage_increase(initial,final):
    return str( int( ((final - initial) / initial) * 100))+" % on average"

# %%
#quick peek at our data
df.describe(include='all')
#df.head(10)
# Out:
#         total_bill         tip   sex smoker  day eating_time  table_size  \
# count   244.000000  244.000000   244    244  244         244  244.000000
# unique         NaN         NaN     2      2    4           2         NaN
# top            NaN         NaN  Male     No  Sat      Dinner         NaN
# freq           NaN         NaN   157    151   87         176         NaN
# mean     19.785943    2.998279   NaN    NaN  NaN         NaN    2.569672
# std       8.902412    1.383638   NaN    NaN  NaN         NaN    0.951100
# min       3.070000    1.000000   NaN    NaN  NaN         NaN    1.000000
# 25%      13.347500    2.000000   NaN    NaN  NaN         NaN    2.000000
# 50%      17.795000    2.900000   NaN    NaN  NaN         NaN    2.000000
# 75%      24.127500    3.562500   NaN    NaN  NaN         NaN    3.000000
# max      50.810000   10.000000   NaN    NaN  NaN         NaN    6.000000
#
#         tip_percentage
# count       244.000000
# unique             NaN
# ...

# %% [markdown]
# ##End of Answer 1##

# %% [markdown]
# # Task 2: Second pass - individual features and target

# %% [markdown]
# ##Start of Answer 2##

# %% [markdown]
# We have 4 categorial varialbes(sex, smoker, day , eating_time) and 3 numeric variables(total_bill, tip, table_size)

# %% [markdown]
# # TIPS
# #  2.1-When do people tip the most ?

# %% [markdown]
# Our main target is  the tip amount so let's see some informations about that

# %% [markdown]
# ### -------------------------------------Numerical Features-------------------------------------

# %% [markdown]
# ## 2.1.1-Tip_amount distribution

# %%
#Let's plot the tip values(rounded-up) by the number of occurence to see if it follow a specific distribution(normal)
df['tip_rounded_up'] = ( (df.tip*2).round() )/2 
#We multiply and then round up to add more precision

#Plot with a histogram to show the number of occurence

plt.hist(df['tip_rounded_up'],bins=40)

plt.xlabel("Tip Amount")
plt.ylabel("Number of occurence")
plt.title("Distribution of tips amounts by number of occurence")

plt.show()
print("By the look of the plot it kind of ressemble a normal distribution")

#Basic statistical values
df.tip.agg(["min","max", "mean", "count", "std"])
# Out:
# By the look of the plot it kind of ressemble a normal distribution
# min        1.000000
# max       10.000000
# mean       2.998279
# count    244.000000
# std        1.383638
# Name: tip, dtype: float64

# %% [markdown]
# ## 2.1.2-Tip_percentage and tip : Is there a social norm ?(fixed tip percentage)

# %% [markdown]
# In numerous countries the tip amount follow a certain distribution(secret guidelines to not appear either cheap or too generous)
#
# For example in France the tip amount is already included in the bill(15% of the total_bill) so we don't have to tip unless we really want to. Of course there is some fluctuation for bad/excellent service
#
# If every tip_percentage is the same, then we can conclude that the only features that matters is the total_bill, if there is fluctuation then we will look around for others feature
#
# Let's see if it's the same for this dataset, we will use of histogram to check the distribution then we will look at the possible outliers or extreme values to see if there is an explanation

# %%
sns.histplot(df.tip_percentage)
plt.title("Distribution of tip_percentage")
plt.show()

# %% [markdown]
# Let's see the outliner and see if there is interesting redundant factors

# %%
#Outliner calculation
# IQR rule (IQR = Q3 — Q1)
#Lower and Upper boundaries : Q1–1.5 * IQR and Q1+1.5 * IQR

df[['tip_percentage']].describe()
# Out:
#        tip_percentage
# count      244.000000
# mean        16.080258
# std          6.107220
# min          3.563814
# 25%         12.912736
# 50%         15.476977
# 75%         19.147549
# max         71.034483

# %%
Q1 = df['tip_percentage'].quantile(0.25)
Q3 = df['tip_percentage'].quantile(0.75)

IQR = Q3 - Q1

Lower_boundary = Q1-1.5*IQR 
Upper_boundary = Q3+1.5*IQR
print("The Lower boundary is :", Lower_boundary)
print("The Upper boundary is :", Upper_boundary)
# Out:
# The Lower boundary is : 3.5605174862758684
# The Upper boundary is : 28.49976732103248

# %% [markdown]
# That means that every values outside of these boundaries will be considered outliers, let's check if these outliers can tell us something interesting

# %%
#superior to the Upper boundary

df[df['tip_percentage']>Upper_boundary]
# Out:
#      total_bill   tip     sex smoker  day eating_time  table_size  \
# 67         3.07  1.00  Female    Yes  Sat      Dinner           1
# 172        7.25  5.15    Male    Yes  Sun      Dinner           2
# 178        9.60  4.00  Female    Yes  Sun      Dinner           2
# 232       11.61  3.39    Male     No  Sat      Dinner           2
#
#      tip_percentage  tip_rounded_up
# 67        32.573290             1.0
# 172       71.034483             5.0
# 178       41.666667             4.0
# 232       29.198966             3.5

# %%
#Inferior to the Lower Boundary

df[df['tip_percentage']<Lower_boundary]
df.nsmallest(5, 'tip_percentage')
# Out:
#      total_bill   tip     sex smoker  day eating_time  table_size  \
# 237       32.83  1.17    Male    Yes  Sat      Dinner           2
# 102       44.30  2.50  Female    Yes  Sat      Dinner           3
# 57        26.41  1.50  Female     No  Sat      Dinner           2
# 0         16.99  1.01  Female     No  Sun      Dinner           2
# 187       30.46  2.00    Male    Yes  Sun      Dinner           5
#
#      tip_percentage  tip_rounded_up
# 237        3.563814             1.0
# 102        5.643341             2.5
# 57         5.679667             1.5
# 0          5.944673             1.0
# 187        6.565988             2.0

# %% [markdown]
# There is no bottom outliers but we can quickly check the lowest values if there is something.

# %% [markdown]
# ### Interpetation :
#
# As expected most people tip between 10 and 25 percent of the total_bill, it confirm that there is a tendency based on the tip_percentage therefore the total_bill influence the tip_amount (tip_percentage comes from total_bill)
#
# We can see from the Upper outliers that it only happens when the total_bill is really low, it makes sense because it you pay 3€ you won't necessarily tip 20% of 3€(which is 60cents)
#
# From the bottem values, there is no obvious reasons.
#
# One thing worth nothing is that these 'extremes values' only takes places during Dinner time

# %% [markdown]
# ## 2.1.3-Total_bill and tip :
# Does the tip amount increase in general when the bill is higher ? We will use a linearplot to see

# %%
sns.lmplot(x="total_bill", y="tip", data=df);
plt.title("Tip amount by total_bill")
plt.show()
df[["total_bill", "tip"]].corr()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 sns.lmplot(x="total_bill", y="tip", data=df);
#       2 plt.title("Tip amount by total_bill")
#       3 plt.show()
#
# NameError: name 'sns' is not defined

# %% [markdown]
# ### Interpetation :
#
#
# From the scatterplot we can see that there is a positive relationship,
# the pearson's correlation coefficient r=0.675, shows a positive linear relationship

# %% [markdown]
# ## 2.1.4-Size of group and tip:
#  We might suppose than when there is more people the people tend to tip more.
# We might also check in task 3 the relationship between the size and total_bill and the influence on the target

# %%
sns.lmplot(x="table_size", y="tip", data=df);
plt.title("Tip amount by table_size")

df[["table_size", "tip"]].corr()
# Out:
#             table_size       tip
# table_size    1.000000  0.489299
# tip           0.489299  1.000000

# %% [markdown]
# #### Interpetation :
#
#
# From the scatterplot we can see that there is a positive relationship,
# the pearson's correlation coefficient r=0,489, shows a positive linear relationship

# %% [markdown]
# ### -------------------------------------Categorical features-------------------------------------

# %% [markdown]
# ## 2.1.5-Gender and tip :

# %%
#barplot of gender
sns.barplot(x = df.tip, y =df.sex)
plt.title("Tip amount by sex")

df[['tip','sex']].groupby('sex').mean().reset_index()
# Out:
#       sex       tip
# 0  Female  2.833448
# 1    Male  3.089618

# %% [markdown]
# Let's look deeper into the relation between gender and tip amount
#
#
# On average Male tip slighty more than female
#
# Let's see if gender has an effect on the tip amount
#
# H0 = Gender has no effect(MaleTipAmount=FemaleTipAmount),
# H1 = Gender has an effect (MaleTipAmount!=FemaleTipAmount)
#
# Let's suppose than H0 is true

# %%
dfGender = df[['tip','sex']].groupby('sex').mean().reset_index()

#May look back into that
#reduced centered value
print( "Gender reduced centered value :",(dfGender.tip[1]-dfGender.tip[0])/std_tip )
# Out:
# Gender reduced centered value : 0.18514201224653856

# %% [markdown]
# We look up the value of Z in the Standard Normal Distribution Table with 0,1 for decimals and 0.08 for hundredths, it gives us : 0.5714
#
# Table : https://archimede.mat.ulaval.ca/stt1920/STT-1920-Loi-normale.pdf
#
# ### Interpetation :
#
#
# We want to probability of a value that is farther than Z so we do 1-0.57 = 0.43
# 0.43 >0.05(alpha) so we can't reject H0, but that doesn't mean that  H1 is true(alpha is usually around 0.05)
#
# Even so the difference is not that big between gender
#
# (We made quite big calculation(HO,H1,normal distribution...), for similar values, we will just skip these steps

# %% [markdown]
# ## 2.1.6-Eating_time lunch/dinner and tip :
# we can conjecture that people spend more during dinner time :

# %%
df.groupby('eating_time')['tip'].agg(["min","max", "mean", "count", "std"])
# Out:
#               min   max      mean  count       std
# eating_time
# Lunch        1.25   6.7  2.728088     68  1.205345
# Dinner       1.00  10.0  3.102670    176  1.436243

# %%
print("Eating at dinner bring an increase of :", percentage_increase(2.728,3.102) )
# Out:
# Eating at dinner bring an increase of : 13 % on average

# %% [markdown]
# ### Interpetation :
#
# On average people tip more during dinner than during lunch(13% more), but it is the explanatory variable?
#
# We might look if it's not because the size is greater during dinner or the total_bill -multicollinearity, principal component analysis on later part?
# we will answer that in the Task 3

# %% [markdown]
# ## 2.1.7-Day and tip :
# We suppose that on the weekend or on friday people will spend more

# %%
sns.boxplot(data=df, x="tip", y="day")
plt.title("Boxplot of tip amount by eating day")
# Out:
# Text(0.5, 1.0, 'Boxplot of tip amount by eating day')

# %%
df.groupby('day')['tip'].agg(["min","max", "mean", "count", "std"])
# Out:
#        min    max      mean  count       std
# day
# Thur  1.25   6.70  2.771452     62  1.240223
# Fri   1.00   4.73  2.734737     19  1.019577
# Sun   1.01   6.50  3.255132     76  1.234880
# Sat   1.00  10.00  2.993103     87  1.631014

# %% [markdown]
# ### Interpetation :
# People spend more on the weekend(especially on sunday)
#
# Interestingly enough the number of people who eat out on Friday is really low(not even a third of the 2nd lowest value)
#
# We may ask ourself if the tip_amount increase is really due to the day or a result of multicolinarity (between eating_time and Day -On certain day the total_bill is higher and the total_bill is strongly correlated to the tip_amount) we will answer that in the Task 3

# %% [markdown]
# ## 2.1.8-Smoker and tip :
# We can conjecture that this feature is not really related to the target but let's be sure

# %%
sns.boxplot(data=df, x="tip", y="smoker")
plt.title("boxplot of tip amount by being a smoker or not")
# Out:
# Text(0.5, 1.0, 'boxplot of tip amount by being a smoker or not')

# %%
df.groupby('smoker')['tip'].agg(["min","max", "mean", "count", "std"])
# Out:
#         min   max      mean  count       std
# smoker
# No      1.0   9.0  2.991854    151  1.377190
# Yes     1.0  10.0  3.008710     93  1.401468

# %% [markdown]
# ### Interpetation :
# As we can see being a smoker or not doesn't really matter for the tip amount...

# %% [markdown]
# ## Main conclusion :
#
# To conclude : total_bill, table_size, eating_time and day seems to have an impact with the tip value.
#
# Smoking or Gender doesn't seems to have an impact

# %% [markdown]
# ## 2.2 -When are the table_size the largest ?

# %% [markdown]
# In this part we will quickly study how some feature interact with the table_size we can ask ourself some questions :
#
# -Do male or female tend to eat in bigger groups
#
# -Are smoker more social than non smoker ?
#
# -Is the group bigger on lunch time or on dinner time?
#
# -On which day are group bigger
#
#
#
# Determining these factor may be interesting because has we have just seen before, the table_size is correlated with the tip amount(and surely with the total_bill but we will know for sure in the next section)
# It can also be useful for the restaurant, especially the 2 last points(so they can prepare better and avoid being short-handed).
#
#
# After this can also check if people behave differently if the group is bigger(to show off or just because till total_amount is bigger)

# %% [markdown]
# ### -------------------------------------Numerical features-------------------------------------

# %% [markdown]
# We won't study the total_bill, tip, tip_percentage because those variables are decided AFTER chosing the group_size(your group_size is generally set before you pay and tip)

# %% [markdown]
# ### -------------------------------------Categorical features-------------------------------------

# %% [markdown]
# We can conjecture that gender, being a smoker or not doesn't influence table_size, but the day and eating time may influence the table_size

# %%
#Group size variation :size vary with etaing_time/day/smoker

features = df[['smoker','eating_time','day','sex']]


#for f in features:
    #g = sns.FacetGrid(features, col=f)
    #g.map(sns.countplot, "table_size")

for f in features:
    sns.violinplot(data=df, x="table_size", y=f)
    plt.title("violin plot of table_size by "+str(f))
    plt.show()

# %% [markdown]
# From this plot we can confirm that smoking is not really related to table_size, people tend to be in larger group for Dinner and on Sunday, let's look at the mean and the std for each feature

# %% [markdown]
# ### 2.2.1-Smoking and table_size - Does it bring a big difference ?

# %%
df.groupby('smoker')['table_size'].agg(["mean", "std"])
# Out:
#             mean       std
# smoker
# No      2.668874  1.017984
# Yes     2.408602  0.810751

# %%
print("Not smoking bring an increase of :", percentage_increase(2.408,2.668) )
# Out:
# Not smoking bring an increase of : 10.79734219269104 %

# %% [markdown]
# Not smoking bring around a 11% increase on average in table_size

# %% [markdown]
# ### 2.2.2-Eating_time and table_size - Does it bring a big difference ?

# %%
df.groupby('eating_time')['table_size'].agg(["mean", "std"])
# Out:
#                  mean       std
# eating_time
# Lunch        2.411765  1.040024
# Dinner       2.630682  0.910241

# %%
print("Eating at dinner time bring an increase of :", percentage_increase(2.411,2.630) )
# Out:
# Eating at dinner time bring an increase of : 9.083367897138112 %

# %% [markdown]
# On dinner, there is around a 9% increase on average table_size

# %% [markdown]
# ### 2.2.3-Day and table_size - Does it bring a big difference ?

# %%
df.groupby('day')['table_size'].agg(["mean", "std"])
# Out:
#           mean       std
# day
# Thur  2.451613  1.066285
# Fri   2.105263  0.567131
# Sun   2.842105  1.007341
# Sat   2.517241  0.819275

# %%
#For this one we will highlight the difference between the lowest and highest mean and the the smalest difference
print("Largest increase", percentage_increase(2.105, 2.842) )
print("Smallest increase", percentage_increase(2.451, 2.517))
# Out:
# Largest increase 35.011876484560574 %
# Smallest increase 2.692778457772331 %

# %% [markdown]
# Eating on Sunday instead of on Friday bring a 35% increase on average table_size ! But eating on Thursday instead of Saturday doesn't mean much...

# %% [markdown]
# ### 2.2.4-Sex and table_size - Does it bring a big difference ?

# %%
df.groupby('sex')['table_size'].agg(["mean", "std"])
# Out:
#             mean       std
# sex
# Female  2.459770  0.937644
# Male    2.630573  0.955997

# %%
print("Being a male bring an increase  :",percentage_increase(2.459, 2.630))
# Out:
# Being a male bring an increase  : 6.954046360309062 % on average

# %% [markdown]
# Being a male slighly increase the average table_size

# %% [markdown]
# ## Main Conclusion :
# **Eating_time and smoker have a quite a bit of influence on table_size, the feature that has the most influence is the day(at most 26% increase on average table_size).Gender has little influence in table_size**

# %% [markdown]
# ## 2.3-When do people pay the most(total_bill) ?

# %% [markdown]
# #table_size,tip sex,smoker, day, eating_time
#
# We can ask ourself if people pay more when it's a men/woman, ->we will make a boxplot/violonplot to compare the category
#
# We can conjecture that it will be higher when the group is bigger ->we will make a lmplot to see the direction of the line
#
# Also when the tip_amount is bigger(we already know)
#
# Ask ourself on which day people pay more ?(probably doesn't matter) ->violon plot(categorical)
#
# We can conjecture that people spend more on dinner-> violon plot or boxplot(categorical)

# %% [markdown]
# ### -------------------------------------Numerical features-------------------------------------

# %% [markdown]
# ### 2.3.1-Table_size and total_bill

# %%
#relationship between table_size and total_bill
sns.lmplot(x="total_bill", y="table_size", data=df);
plt.title("total_bill by table_size")

df[["total_bill", "table_size"]].corr()
# Out:
#             total_bill  table_size
# total_bill    1.000000    0.598315
# table_size    0.598315    1.000000

# %% [markdown]
# ### Interpetation :
# From the look of the plot, **total_bill and table_size are correlated as expected, the pearson's coefficient r=0.598 shows a positive realationship**

# %% [markdown]
# ### 2.3.2-Tip and total_bill

# %% [markdown]
# **We already saw this relationship (in 2.1.3),the pearson's coefficient r=0,675, shows a positive linear relationship it is correlated.**

# %% [markdown]
# ### -------------------------------------Categorical features-------------------------------------

# %% [markdown]
# ### 2.3.3-Gender and total_bill does it matter ?

# %%
#barplot of gender
sns.boxplot(x = df.total_bill, y = df.sex)
plt.title("boxplot of total_bill amount by sex")
sns.displot(df, x="total_bill", hue="sex", element="step")
plt.title("Total bill based on gender")
df[['total_bill','sex']].groupby('sex').mean().reset_index()
# Out:
#       sex  total_bill
# 0  Female   18.056897
# 1    Male   20.744076

# %%
print("Being a male bring an increase  :",percentage_increase(18.056, 20.744))
# Out:
# Being a male bring an increase  : 14.887018165706683 % on average

# %% [markdown]
# ### Interpetation :

# %% [markdown]
# On average Male spend slightly more than Female (around 15% more), we can also note that the upper whisker for Male go more to the right than the Female's one, and for the woman the bottom whisker go more to the left than the Male's one.

# %% [markdown]
# ### 2.3.4-Day and total_bill does it matter ?

# %%
sns.boxplot(x = df.total_bill, y =df.day)
plt.title("boxplot of total_bill amount by day")

df[['total_bill','day']].groupby('day').mean().reset_index()
# Out:
#     day  total_bill
# 0  Thur   17.682742
# 1   Fri   17.151579
# 2   Sun   21.410000
# 3   Sat   20.441379

# %%
#For this one we will highlight the difference between the lowest and highest mean and the the smalest difference
print("Largest increase", percentage_increase(17.151, 21.41) )
print("Smallest increase", percentage_increase(17.151, 17.682))
# Out:
# Largest increase 24 % on average
# Smallest increase 3 % on average

# %% [markdown]
# ### Interpetation:
#
# As we can see and as expected **people spend more on the weekend than in the week(a 24% difference for extreme value)**, we can also ask ourself if it's the main reason ?
#
# Or just because as we seen in the previous section that **the group_size is larger on the weekend therefore the total_bill increase, we will answer that in the Task 3.**

# %% [markdown]
# ### 2.3.5-Eating_time and total_bill does it matter ?

# %%
sns.boxplot(x = df.total_bill, y = df.eating_time)
plt.title("boxplot of total_bill amount by eating_time")

sns.displot(df, x="total_bill", hue="eating_time", element="step")
plt.title("Total bill based on eating_time")

df[['total_bill','eating_time']].groupby('eating_time').mean().reset_index()
# Out:
#   eating_time  total_bill
# 0       Lunch   17.168676
# 1      Dinner   20.797159

# %%
print("Eating on dinner instead of lunch bring an increase of", percentage_increase(2.105, 2.842) )
# Out:
# Eating on dinner instead of lunch bring an increase of 35 % on average

# %% [markdown]
# ### Interpetation :
#
# As expected **the total_bill is generally way bigger on the dinner(35% increase)**, we can also note that on dinner the wisker are much larger, and both have some outliers towards the left.

# %% [markdown]
# ### 2.3.6 Smoker and total_bill does it matter ?

# %%
sns.boxplot(x=df.total_bill, y=df.smoker)
plt.title("boxplot of total_bill amount by smoker")
plt.show()

sns.violinplot(x=df.total_bill, y=df.smoker)
plt.title("violin of total_bill amount by smoker")
plt.show()

sns.displot(data =df, x="total_bill", hue="smoker", element="step")
plt.title("Total bill based on smoker")


df[['total_bill','smoker']].groupby('smoker').mean().reset_index()
# Out:
#   smoker  total_bill
# 0     No   19.188278
# 1    Yes   20.756344

# %%
print("Being a smoker bring a", percentage_increase(19.1888, 20.756) )
# Out:
# Being a smoker bring a 8 % on average

# %% [markdown]
# ### Interpetation :
# From the increase %, we can tell that **smoking or not doesn't have much of an effect**, the boxplot may be misleading so we also plotted a violin plot.
# Smokers do have a wider range(larger whiskers)

# %% [markdown]
# ## Main conclusion :
#
# In order to have the **maximum bill on average, it's good if the table_size and tip_amount is big, we eat at dinner and on the weekend(sunday) also, surprisingly the gender has quite a big effect(a 15% increase on average).**
#
# One hypothesis is that maybe Male tend to be in larger_size or go out more often on the weekend/diner. we will dive deeper in task 3
#
# Smoking doesn't bring much of a difference...

# %% [markdown]
# # Task 2 Summary   :
#
#
# To conclude :
#
# Tip :
#
# **total_bill, table_size, eating_time and day seems to have an impact with the tip value. We will plot these features together and make a heatmap to emphasis sign and magnitude of correlation**
#
# Smoking or Gender doesn't seems to have that much of an impact on tip
#
# Table_size:
#
# **Gender, eating_time and smoker have a very little influence on table_size, the feature that has the most influence is the day(at most 26% increase on average table_size)**. We will see in task 3 when is the table_size the largest when we cross those features.
#
# Total_bill:
#
# **For the total bill, we found that the sex has a effect(maybe not direct eating_time/day/table_size).
# The total bill does increase with the table_size as expected with the day(weekend) , eating_time(dinner) and tip_amount(we knew that)**
#
# Let's then see the relationships between these values and how do they influence each other in task3.

# %% [markdown]
# ##End of Answer 2##

# %% [markdown]
# # Task 3: Third pass - relationships between features and target

# %% [markdown]
# ##Start of Answer 3##

# %%
#See how do tip amount change with threshold like groupsize >4 or total_bill >40

# %% [markdown]
# ### In task 2 we saw the relationship between one feature  at a time and our target. Let's check this time with a phik_matrix that will display the phik's coefficient between all our features and target.

# %%
#interval_cols = []

df_phik = df[['smoker', 'sex', 'day', 'eating_time', 'tip_percentage','table_size','total_bill','tip']]

phik_overview = df_phik.phik_matrix(['tip_percentage'])
phik_overview.round(2)

#from https://towardsdatascience.com/phik-k-get-familiar-with-the-latest-correlation-coefficient-9ba0032b37e7
plot_correlation_matrix(phik_overview.values, 
                        x_labels=phik_overview.columns, 
                        y_labels=phik_overview.index, 
                        vmin=0, vmax=1, color_map="Greens", 
                        title=r"correlation $\phi_K$", 
                        fontsize_factor=1.5, 
                        figsize=(10, 8))
plt.tight_layout()

# %% [markdown]
# When studying this heatmap, I realised that it's really weird that the total_bill/tip are not correlated with day, because in our previous analysis we know for sure that the day has something to do with them(pearson's coefficient), be it directly or indirectly. In order to answer our questions we may :
#
# -Merge saturday/sunday into weekend and thursday/ friday into week to highlight the difference(the coefficient is surely hidden by the fact that there is 4 possible values and between thursday and friday there is not much difference, the same for sunday/saturday).

# %%
#new columns weekend instead of day
df['week_end'] = df['day'].isin(['Sat', 'Sun'])
df.week_end.unique()
#df.day = pd.Categorical(df.day, categories=['Thur', 'Fri','Sun', 'Sat'], ordered=True) #no service on Monday and Tuesday
#df.day.unique()
#df.head()


df_phik = df[['smoker', 'sex', 'week_end', 'eating_time', 'tip_percentage','table_size','total_bill','tip']]
phik_overview = df_phik.phik_matrix(['tip_percentage'])
phik_overview.round(2)

#from seaborn documentation
plot_correlation_matrix(phik_overview.values, 
                        x_labels=phik_overview.columns, 
                        y_labels=phik_overview.index, 
                        vmin=0, vmax=1, color_map="Greens", 
                        title=r"correlation $\phi_K$", 
                        fontsize_factor=1.5, 
                        figsize=(10, 8))
plt.tight_layout()

# %% [markdown]
# This heatmap makes more sense, now the total_bill is correlated to the week_end, the table_size has also a higher correlation with the week_end, and the smoker correlation with the week_end vanished !

# %% [markdown]
# ### Discussion and Hypothesis
#
# So based on this heatmap(the second one), there is quite a lot to discuss, the first thing to highlight is that : the tip here is correlated uniquely to table_size(0.64) and total_bill by quite a lot(0.99 !) .And that eating_time, day, sex and smoker are not phik correlated with tip !
# \
# \
# \
# This piece of information clash with what we found in part2 with individials feature(pearson's coefficient 1 feature at a time) but it perfectly make sense and answer some hypothethis that we had before .
#
# -Does the tip amount increase because of the day, OR the tip amount increase because on certains days the total_bill/table_size is on average higher ?
#
# -Does the tip amount increase because of the eating_time, OR the tip amount increase because on dinner the total_bill is on average higher(we know that thanks to section 2.3.5) ?
#
# -Is the total_bill increase due to sex, OR because male go out in larger group or more on the weekend/dinner than the female ?
#
# -One additional piece of information is that eating_time and day are very strongly correlated(0.98) we can deduce that on certain day people would highly favor an eating_time than the other.
# \
# \
# \
# Let's now look at the total bill :
#
# -relation with eating_time and surprisingly with sex(eating_time and weekend implications with sex).
#
# -no relation with table_size ???(it clashes with what we found in section 2.3.1 : total_bill and table_size positively correlated).
# \
# \
# \
# Let's look at the table_size because the table_size is correlated with the tip.
#
# -As we have seen in part 2.2, the table_size is correlated with the eating_time(more on dinner) and with the weekend. In the later part we will see how much of a difference it means if we fuse these 2 parameters.
#
# -As for sex and smoker there is also a small correlation that join our study in part 2.2.1(smoker) and 2.2.4(sex) - not that much of a deal.
#
# -We can also note that sex is correlated with tip_percentage and tip_percentage is correlated with table_size.

# %% [markdown]
# ## 3.1-When do people tip the most ?

# %% [markdown]
# ### 3.1.1 -Related feature with phik's correlation (Tip with total_bill and table_size)

# %% [markdown]
# Let's see how features interacts with each other with the Pearson's Correlation Coefficient(only numerical).
#
# Let's also use a heatmap to emphasise the correlations and magnitude of each variables.

# %%
corr = df[['tip','total_bill','table_size']].corr()

sns.heatmap(corr,vmin=-1, vmax=1,annot=True)
plt.title("Correlation of tip, total_bill and table_size")
corr
# Out:
#                  tip  total_bill  table_size
# tip         1.000000    0.675734    0.489299
# total_bill  0.675734    1.000000    0.598315
# table_size  0.489299    0.598315    1.000000

# %% [markdown]
# All of these variabels are all positively correlated with each others here, we can also note that the total_bill is more positively correlated than the table_size.

# %%
#tip by size and total_bill
g = sns.PairGrid(df, y_vars=["tip"], x_vars=["total_bill", "table_size"], height=4)
plt.title("Pairplot of total_bill and table_size for tip", x=-0)

g.map(sns.regplot)

# %% [markdown]
# These 2 features positively correlate with the tip, let's plot these both together

# %%
sns.relplot(data=df, x="total_bill", y="tip",size="table_size", sizes=(10, 300))
plt.title("Tip value with the total bill and size")
#Check is there is not a better representation
# Out:
# Text(0.5, 1.0, 'Tip value with the total bill and size')

# %% [markdown]
# ### Conclusion :
#
# We can see that there is a tendency that when we move to the top-right, points are bigger(table_size)
# **With this plot we can conclude that the tip increase with table_size and total_bill**(these 2 are surely the explanatory variable for the tip amount)

# %% [markdown]
# ### 3.1.2 -Non-Related feature with phik's correlation (Tip with eating_time, week_end, smoker and gender)

# %% [markdown]
# We will plot those the categorical features in 2 group :
#
# -Features that we concluded in part 2.1 that seem to have a positive effect(day/eating_time)
#
# -Features that we concluded in part 2.1 that don't seem to have an effect

# %%
sns.violinplot(x="week_end", y="tip", hue="eating_time", data=df);
plt.title("Violinplot of tip based on week_end and eating_time")
# Out:
# Text(0.5, 1.0, 'Violinplot of tip based on wee_end and eating_time')

# %% [markdown]
# ### Interpetation :
# From this violinplot, we can see that on lunch, there are **more people that tip less compared to dinner time, being on a week_end seems to have more outliers towards the top.**
#
# This plot disagree with the phik_matrix(no correlation), **we can deduce that these features indirectly interact in a positive way with the tip_amount**

# %%
sns.boxplot(x="sex", y="tip", hue="smoker", data=df);
plt.title("boxplot of tip based on smoking and gender")
# Out:
# Text(0.5, 1.0, 'boxplot of tip based on smoking and gender')

# %% [markdown]
# ### Interpetation :
#
# With this boxplot with smoker and gender we can see that the Q3 are roughly the same but the Q2 of Males/Females that smokes are slightly higher. In task 2.2 we saw that smoking slightly increase the table_size and therefore the tip(but not by much) and in task 2.1.8 we found that the smoking is a really really small increase on tip(negligeable)
#
# We can note that Male have higher whisker than female and more outliers, if we zoom close enough the Q2 and Q3 of Males are higher than those of Females.
#
# It kinda reinforce our hypothethis that Male increase the tip_amount indirectly(table_size/total_bill(eating_time/week_end))

# %% [markdown]
# ## Main conclusion :
# With the phik and pearson's correlation factors, we can see that the **features that directly contribute to the tip amount are the table_size and the total_bill**, so far it makes sense with our previous hypothesis (tiping amount follow a certain distribution based on total_bill, there is more people so the total_bill go up +social factors).
#
# Because those features increase the tip_amount, that means that **any features that increase directly or indirectly the table_size and total_amount would indirectly increase the tip_amount**(week_end and eating_time), we will look at them in the next section
#
# In the next section we should really try to understand why the phik-matrix say that the table_size is not correlated with the total_bill(hypothesis on the formula : problem from the order difference(Ordre de grandeur).
#
# One other possibility is that I have assumed that it was a restaurant but maybe it's more like brunch when 4 people can each take a cake(or drink) at 4€ and 2 people can eat a main meal at 10€

# %% [markdown]
# ## 3.2-When are the table_size the largest ?

# %% [markdown]
# On task 2 we found out that :
# Eating_time and smoker have a little positive influence on table_size.
#
# The feature that has the most positive influence is the day.
#
# Gender has very little influence in table_size.
#
# Let's see how these variables interact with each other for the table_size

# %% [markdown]
# ### 3.2.1-Table_size by day/eating time and gender

# %%
#Also make a multi values plot
#smoker doesn't influence much so let's remove it for simplier reading
#df.groupby(['smoker','eating_time','day'])['table_size'].agg(["min","max", "mean", "count", "std"])
df.groupby(['sex','eating_time','day'])['table_size'].agg(["min","max", "mean", "count", "std"])
# Out:
#                          min  max      mean  count       std
# sex    eating_time day
# Female Lunch       Thur  1.0  6.0  2.483871     31  1.150970
#                    Fri   2.0  3.0  2.250000      4  0.500000
#                    Sun   NaN  NaN       NaN      0       NaN
#                    Sat   NaN  NaN       NaN      0       NaN
#        Dinner      Thur  2.0  2.0  2.000000      1       NaN
#                    Fri   2.0  2.0  2.000000      5  0.000000
#                    Sun   2.0  5.0  2.944444     18  0.937595
#                    Sat   1.0  4.0  2.250000     28  0.700529
# Male   Lunch       Thur  2.0  6.0  2.433333     30  1.006302
#                    Fri   1.0  2.0  1.666667      3  0.577350
#                    Sun   NaN  NaN       NaN      0       NaN
#                    Sat   NaN  NaN       NaN      0       NaN
#        Dinner      Thur  NaN  NaN       NaN      0       NaN
#                    Fri   2.0  4.0  2.285714      7  0.755929
# ...

# %% [markdown]
# ### Interpetation :
#
# By the look of the dataframe we can note that the **table are the largest for the Sunday Dinner** Time(both for Female and for Male)
#
# One other thing worth mentionning is that on **the week_end(saturday and sunday), there is no record of Lunch. It is important to note because we know that people spend more on dinner than on lunch**
#
# We will plot a count plot and a ecdf plot to better understand to see the difference by gender and smoker in table_size
#
# ecdf=proportion of observations below a unique value

# %% [markdown]
# ### 3.2.2-Table size by gender only

# %% [markdown]
# On the phik_matrix we don't have any obvious clue - maybe tip percentage ?

# %%
sns.countplot(data=df, x="table_size", hue="sex")
plt.title("Countplot of table_size by gender")
plt.show()

sns.ecdfplot(data=df, x="table_size", hue="sex")
plt.title("ecdfplot of table_size by gender")
# Out:
# Text(0.5, 1.0, 'ecdfplot of table_size by gender')

# %% [markdown]
# ### Interpetation :
# Actually thanks to the ecdfplot we see that the **proportion for table_size for gender is pretty much the same, we can deduce that the gender doesn't have an direct influence on table_size**.-In accordance to task 2.
#
# But on the data show in 3.2.1 we can see that on average Males have a very slightly bigger table_size, why is that ? We can remember in part 2.3 that the table_size very dependent on the day. It reinforces our hypothesis that male go out more on the week_end

# %% [markdown]
# ### 3.2.3 -Why is the table_size not correlated with the total_bill on the phik_matrix

# %% [markdown]
# We will look at the total_bill mean based on table_size to try to draw a conclusion and choose whether we keep our hypothesis that the total_bill in correlated with the table_size in task 2 or we keep the hypothethis by the phik_matrix that the table_size is not correlated with the total_bill

# %%
df[['table_size','total_bill']].groupby(['table_size']).mean()
# Out:
#             total_bill
# table_size
# 1             7.242500
# 2            16.448013
# 3            23.277632
# 4            28.613514
# 5            30.068000
# 6            34.830000

# %% [markdown]
# As we can see when the total_bill is in ascending order with the table_size.
# I will kill my previous hypothethis on task 2, with pearson's correlation : table_size is correlated with total_bill

# %% [markdown]
# ## Main Conclusion :
#
# By the look of the dataframe we can note that the **table are the largest for the Sunday Dinner** Time(both for Female and for Male).
#
# One other thing worth mentionning is that on the week_end(saturday and sunday), there is no record of Lunch. It is important to note because we know that **people spend more on dinner than on lunch.**
#
# Gender doesn't have a direct effect on table_size
#
# We concluded to choose the hypothesis in task 2: the table_size is correlated with total_bill
#
# **on average Male tend to have a bigger table_size(probably because they go out more on the week-end and on the week-end, the table_size are generally bigger)**

# %% [markdown]
# ## 3.3- Total_bill
# ### Let's try to explain why the gender has an effect on total_bill and why it doesn't affect percentage

# %% [markdown]
# We know that on dinner people tend to spend more than on lunch, but the phik coefficient indicate no positive relationship with the table_size and it clash with our result on 2.3.1(that the total_bill increase with the size), we will try to find a answer.
#
# -We also need to explain why the total_bill has a phik coefficient of 0.46 with the sex whereas the tip_percentage has a phik coefficient close to 0 with the sex (hypothethis : this is very likely that one of the 2 gender has a tendency to spend more than the other but keep the same tiping proportion. We will use some countplots with gender and with the eating_time/week_end to see which gender pay more)
#
# -We also know that the total_bill is highly correlated to the eating_time(we know that people spend more on dinner thanks to section 2.3.5) and a phik coefficient of 0.86. So if our first hypothethis is true, we may look if one gender has a tendency to favor a eating_time more than the other
#
# -People spend more on the weekend but is it because people tend to take eat dinner more than lunch on the weekend(probably)?
#
# -If people are dinning more on the weekend, it would be interesting to plot the weekend with the gender,(maybe one sex go out more on the weekend, therefore spend more(because on the week_end people are dinning more) ). It would also help explain the phik value between sex and total_bill. We will use a countplot of week_end with the color represented by sex to see the difference.
#
# -We can also note that the total_bill is not correlated with the table_size weirdly enough but the tip_percentage is, it clashes with the result that we found before but for now I will suppose that the table_size is correlated with the total_bill

# %% [markdown]
# ### 3.3.1- Is one gender favor dinner more than the other ?

# %%
sns.countplot(x='eating_time',data=df,hue='sex')
plt.title('Countplot of people eating out on dinner or lunch by gender')
plt.show()

# %% [markdown]
# ### Interpetation :
#
# We know that people spend more on dinner, therefore increasing the tip_amount but the tip_percentage stay the same, with at lot more Male going out on Dinner that explain why there is a difference in the phik_matrix.
#
# We can deduce that **Males indirectly increase the tip_amount by going out more often than female on dinner**

# %% [markdown]
# ### 3.3.2- Are people going for dinner more on the week-end ?

# %% [markdown]
# We previously saw on multiples plot that on the weekend people dine out way more often but it was never the main focus, this time let's make a countplot to illustrate this relationship

# %%
#show the close relationship between eating_time and week_end
sns.countplot(x='eating_time',data=df,hue='week_end')
plt.title('Countplot of people eating dinner or lunch by week_end')
# Out:
# Text(0.5, 1.0, 'Countplot of people eating dinner or lunch by week_end')

# %% [markdown]
# ### Interpetation :
# On week-end people favor way more dinner and during they don't dine out during the week

# %% [markdown]
# ### 3.3.3-Is one gender has a tendency to go out more on the week-end ?

# %%
sns.countplot(x='week_end',data=df,hue='sex')
plt.title('Countplot of people eating out on the week_end or no by gender')
plt.show()

# %%
#One plot that resume 3.3.1, 3.3.2, 3.3.3
#Orange are male
g = sns.FacetGrid(df, col="week_end",  row="eating_time", hue="sex" ,height=5)
g.map_dataframe(sns.histplot, x="total_bill")
plt.suptitle("orange represent Males", y=1.10)
plt.title("Total_bill by eating_time, week_end and sex",x=0, y= 2.5)
# Out:
# Text(0, 2.5, 'Total_bill by eating_time, week_end and sex')

# %% [markdown]
# ### Interpetation :
#
# We know that people spend more on dinner, therefore increasing the tip_amount. With at lot more Male going out on the week_end and thus having dinner more than female explain why there is a difference in the phik_matrix.
#
# We can deduce that **Males indirectly increase the tip_amount by going out more often than female on the week-end and thus having dinner more often than females**
#
# the percentage_tip doesn't change because Male and Female are tipping the same way, no one is going for lunch on the week_end and only a few go to take dinner during the week. On lunch during the week, Males and Females behave roughly the same way

# %% [markdown]
# ## Main Conclusion :
#
# To summarize, **people tend to have a higher bill on dinner, on week_end people prefer to go dinning, therefore because Males much prefer to go out on the week_end than Females, sex indirectly increase the total_bill** (but the tip_percentage stay the same)

# %% [markdown]
# # Final conclusion :
#
# Thought this part of the notebook we first cleaned the date and changed its features types to categorical, we then asked our self some questions and we studied each target's feature one by one and started to make some more advanced hypothethis.
#
# In the last part, with the phik mattrix, crossing features and the pearson's correlation factors we can have some responses to our hypothesis :
#
# *1)When do people tip the most ?*
#
# *2)When are the table_size the largest ?*
#
# *3)When do people pay the most(total_bill) ?*
#
# 1-
# -The **tipping method kind of follow a set distribution** based on the total_bill, between 10-25%.
#
# -It also increase with the table_size. In task 2 we studied the relation between tip and every features **one by one**, and we
# **saw that all the features can be correlated or have a potentiel increase with the tip**.
# -In task 3, with the phik_matrix and crossing some feature we discovered that only **the total_bill and the table_size directly increase the tip. As for other feature, we will discuss further how do they interact indirectly with the tip** -the main reason for tip increase is total_bill
# \
# \
# 2- As discussed before, it's important to for the **restaurant owner to know when the table_size are the largest or when most people come**.
#
# -In task 2 we found that Gender, eating_time and smoker have a very little influence on table_size, the feature that has **the most influence is the day** and by a lot.
#
# -In task 3 when we **crossed the data we found at than most people would come for dinner during the week-end , some people would come during the week for lunch but no one would come for lunch during the week_end and only a few would come out to eat dinner during the week**.
#
# -**The table_size are also the largest during Saturday/Sunday Night , Males and Females generally go out with the same table_size but Males tend to be in slighly larger groups because they go out more often on the weekend.**
#
# -We decided to keep our hypothesis that the table_size is correlated with the total_bill(pearson's coefficient in task2)
# \
# \
# 3-As mentionned before, **the total_bill is the main factor for the tip**, so it's important that we understand **which features increase the total_bill and so indirectly increase the tip**. **In task 2 we found out that the total_bill tend to increase when the table_size is higher, when people eat during dinner and on the weekend also the gender has quite an effect(Male bring an increase on average)** but we decided to discard smoker(not enough)
# In task 3 we saw how each of them features interact with each others and how do they ultimately bring an increase to the tip :
#
# -We know that **people in general have a higher bill during dinner(so eating_time directly increase tip_amount and indirectly the tip).**
#
# -We know that the **day(weekend) is strongly correlated with the eating_time, on certain day no one is going for lunch, so choosing the right day will increase the amount of dinner taken and thus increase the total_bill(and so the tip)**( day(weekend) interact directly with eating time and interact inderectly to tip_amount and tip
#
#
# -We know that **Males go out more often than female during the weekend(so they positively interact with the day(weekend)), therefore taking more dinner etc...**(gender directly interact with the day(weekend) and indirectly with the eating_time, total_amount,tip.
#
# -We also know that the **Males tend to be in slighly higher group that Females because they go out more on the week_end so the table_size indirectly increase with the Male gender, and so increase the total_bill and the tip**(gender directly interact with the table_size so indirectly interact with the total_bill and tip)

# %% [markdown]
# ## Summary : Influence on tip

# %% [markdown]
# ![schemaTip-3.png](attachment:schemaTip-3.png)

# %% [markdown]
# ##End of Answer 3##

# %% [markdown]
# ##End of EDA 2##
